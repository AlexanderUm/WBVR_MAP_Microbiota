# %%
###################################
# ASV picking using DADA2 pipeline
###################################

# %%
# Prepare folder for dada2 output: 
dir.create("output/2_dada2")

dir.create("output/2_dada2/diagnostic_plots")

dir.create("output/2_dada2/objects")

# %%
# Load libraries 
source("scr/functions/general/load_abs_install_pkg.R")

load_abs_install_pkg(c("dada2", "phyloseq", "tidyverse"))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE

# %%
# Make a list of fastq files in the directory 
path = "data/Dada2_input/"

files <- list.files(path)

files <- files[grep(".fastq", files)]

# %%
# Separate forward and revers reads into different variables 
fnFs <- sort(list.files(path, pattern="R1.fastq", full.names = TRUE))

fnRs <- sort(list.files(path, pattern="R2.fastq", full.names = TRUE))

# %%
# Make a variable containing only files names 
sample.names <- unique(gsub("_R1.fastq|_R2.fastq", "", files))

# %%
# Check reads quality by graphing 
#   Plots are saved in "output/dada2/diagnostic_plots"
forwReads <- plotQualityProfile(fnFs[1:4])

revReads <-plotQualityProfile(fnRs[1:4])

ggsave("output/2_dada2/diagnostic_plots/forward_reads_qualty.pdf", plot = forwReads )

ggsave("output/2_dada2/diagnostic_plots/revers_reads_qualty.pdf", plot = revReads )
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Saving 6.67 x 6.67 in image
# Saving 6.67 x 6.67 in image

# %%
# Prepare directory and names for filtered files 
filtFs <- file.path(path, "filtered", paste0(sample.names, "_F_filt.fastq.gz"))

filtRs <- file.path(path, "filtered", paste0(sample.names, "_R_filt.fastq.gz"))

names(filtFs) <- sample.names

names(filtRs) <- sample.names

# %%
out <- filterAndTrim(fnFs, filtFs, fnRs, filtRs, 
                     truncLen=c(280, 240), # Truncet bad reads at the end of the reads 
                     # however keep in mind that reads should overlap at least 20bp
                     # in our case amplicon is 444 nucleotide long, so total length should be 464 at least. 
                     trimLeft = c(17, 21), # Trim primers from the begining of sequence                       
                     maxN=0, 
                     maxEE=c(1,1), 
                     truncQ=2, 
                     rm.phix=TRUE,
                     compress=TRUE, 
                     multithread=TRUE) #only for Linux
# Out:
# Creating output directory: data/Dada2_input//filtered

# %%
# Check reads number before and after filtering by plotting (personal addition, no needed for DADA2)
#  Prepare data for the plot 
out.gg <- as.data.frame(out)

out.gg$SampleID <- rownames(out.gg)

out.gg.m <- reshape2::melt(out.gg)


# Plot using ggplot package 
filtReads <- ggplot(out.gg.m, aes(x=SampleID, y=value, color=variable, group=SampleID)) + 
             geom_point(size = 3.5) + 
             theme_bw() + 
             geom_line(size = 1) + 
             theme(axis.text.x = element_text(angle = 90, hjust = 1)) + 
             ylab("Reads number")

# Save the plot in output/dada2/diagnostic_plots/ folder 
ggsave("output/2_dada2/diagnostic_plots/n_reads_filter1.pdf", plot = filtReads, width = 12 )
# Out:
# Using SampleID as id variables
# Saving 12 x 6.67 in image

# %%
# Learn errors in sequences for forward and reverse reads 
errF <- learnErrors(filtFs, multithread=TRUE, nbases = 2e8)

errR <- learnErrors(filtRs, multithread=TRUE, nbases = 2e8)

save(list = c("errF", "errR"), file="output/2_dada2/objects/error_rate_FR.RData")
# Out:
# 204404389 total bases in 777203 reads from 26 samples will be used for learning the error rates.
# 208382223 total bases in 951517 reads from 31 samples will be used for learning the error rates.

# %%
errFplot <- plotErrors(errF, nominalQ=TRUE)

errRplot <- plotErrors(errR, nominalQ=TRUE)


# Save plots in output/dada2/diagnostic_plots/
ggsave("output/2_dada2/diagnostic_plots/error_rate_F.pdf", plot = errFplot)

ggsave("output/2_dada2/diagnostic_plots/error_rate_R.pdf", plot = errRplot)
# Out:
# Saving 6.67 x 6.67 in image
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Saving 6.67 x 6.67 in image
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”

# %%
# Dereplication - combine identical sequences into unique with corresponding number 
#                    of reads 
derepFs <- derepFastq(filtFs, verbose=FALSE)

derepRs <- derepFastq(filtRs, verbose=FALSE)

# Name the derep-class objects by the sample names
names(derepFs) <- sample.names

names(derepRs) <- sample.names

# Save dereplicated objects 
save(derepFs, file="output/2_dada2/objects/derepFs.RData")

save(derepRs, file="output/2_dada2/objects/derepRs.RData")

# %%
# Samples inference 
#      *addiotion of (..., pool=TRUE) argument could increase sensetivity for rear variates 
dadaFs <- dada(derepFs, err=errF, multithread=TRUE)

dadaRs <- dada(derepRs, err=errR, multithread=TRUE)

# Back up generated objects 
save(dadaFs, file="output/2_dada2/objects/dadaFs.RData")

save(dadaRs, file="output/2_dada2/objects/dadaRs.RData")
# Out:
# Sample 1 - 25711 reads in 8609 unique sequences.
# Sample 2 - 20402 reads in 10848 unique sequences.
# Sample 3 - 21412 reads in 9209 unique sequences.
# Sample 4 - 18693 reads in 8771 unique sequences.
# Sample 5 - 42664 reads in 20084 unique sequences.
# Sample 6 - 41697 reads in 19934 unique sequences.
# Sample 7 - 18062 reads in 10909 unique sequences.
# Sample 8 - 38713 reads in 19433 unique sequences.
# Sample 9 - 39967 reads in 16433 unique sequences.
# Sample 10 - 47249 reads in 23758 unique sequences.
# Sample 11 - 42551 reads in 20342 unique sequences.
# Sample 12 - 24232 reads in 11046 unique sequences.
# Sample 13 - 22848 reads in 10319 unique sequences.
# Sample 14 - 22982 reads in 10265 unique sequences.
# Sample 15 - 51530 reads in 24836 unique sequences.
# Sample 16 - 16 reads in 13 unique sequences.
# Sample 17 - 40261 reads in 18651 unique sequences.
# Sample 18 - 19352 reads in 10054 unique sequences.
# Sample 19 - 45853 reads in 22904 unique sequences.
# Sample 20 - 40695 reads in 19659 unique sequences.
# Sample 21 - 44818 reads in 22145 unique sequences.
# Sample 22 - 40718 reads in 19981 unique sequences.
# Sample 23 - 6 reads in 5 unique sequences.
# Sample 24 - 22918 reads in 11369 unique sequences.
# Sample 25 - 20676 reads in 9892 unique sequences.
# Sample 26 - 23177 reads in 10612 unique sequences.
# Sample 27 - 39587 reads in 13757 unique sequences.
# Sample 28 - 21180 reads in 12140 unique sequences.
# Sample 29 - 38137 reads in 21402 unique sequences.
# Sample 30 - 34482 reads in 18740 unique sequences.
# Sample 31 - 40928 reads in 19150 unique sequences.
# Sample 32 - 42095 reads in 20711 unique sequences.
# Sample 33 - 38174 reads in 19727 unique sequences.
# Sample 34 - 39066 reads in 17540 unique sequences.
# Sample 35 - 25862 reads in 13363 unique sequences.
# Sample 36 - 20398 reads in 10910 unique sequences.
# Sample 37 - 20587 reads in 11559 unique sequences.
# Sample 38 - 21419 reads in 12544 unique sequences.
# Sample 39 - 21806 reads in 13350 unique sequences.
# Sample 40 - 18213 reads in 10300 unique sequences.
# Sample 41 - 23917 reads in 11753 unique sequences.
# Sample 42 - 29447 reads in 15389 unique sequences.
# Sample 43 - 23241 reads in 13460 unique sequences.
# Sample 44 - 24795 reads in 13885 unique sequences.
# Sample 45 - 20133 reads in 11742 unique sequences.
# Sample 46 - 25652 reads in 13717 unique sequences.
# Sample 47 - 15295 reads in 9081 unique sequences.
# Sample 48 - 28151 reads in 11162 unique sequences.
# Sample 49 - 24003 reads in 10860 unique sequences.
# Sample 50 - 23634 reads in 9672 unique sequences.
# Sample 51 - 22224 reads in 11215 unique sequences.
# Sample 52 - 27605 reads in 12136 unique sequences.
# Sample 53 - 22441 reads in 9817 unique sequences.
# Sample 54 - 31418 reads in 17041 unique sequences.
# Sample 55 - 78162 reads in 32228 unique sequences.
# Sample 56 - 23810 reads in 13099 unique sequences.
# Sample 57 - 43776 reads in 19573 unique sequences.
# Sample 58 - 39610 reads in 19444 unique sequences.
# Sample 59 - 21724 reads in 8969 unique sequences.
# Sample 60 - 25236 reads in 12716 unique sequences.
# Sample 61 - 23302 reads in 11435 unique sequences.
# Sample 62 - 22932 reads in 10879 unique sequences.
# Sample 63 - 37572 reads in 20492 unique sequences.
# Sample 64 - 41987 reads in 20895 unique sequences.
# Sample 65 - 25035 reads in 14507 unique sequences.
# Sample 66 - 38663 reads in 19633 unique sequences.
# Sample 67 - 37800 reads in 19613 unique sequences.
# Sample 68 - 16188 reads in 7845 unique sequences.
# Sample 69 - 21522 reads in 10915 unique sequences.
# Sample 70 - 23239 reads in 7526 unique sequences.
# Sample 71 - 26292 reads in 9123 unique sequences.
# Sample 72 - 37909 reads in 19225 unique sequences.
# Sample 73 - 40226 reads in 17435 unique sequences.
# Sample 74 - 22806 reads in 11264 unique sequences.
# Sample 75 - 43415 reads in 21208 unique sequences.
# Sample 76 - 41346 reads in 18943 unique sequences.
# Sample 77 - 17200 reads in 7283 unique sequences.
# Sample 78 - 22427 reads in 10970 unique sequences.
# Sample 79 - 22271 reads in 9858 unique sequences.
# Sample 80 - 37846 reads in 19143 unique sequences.
# Sample 81 - 43086 reads in 19629 unique sequences.
# Sample 82 - 52 reads in 48 unique sequences.
# Sample 83 - 21431 reads in 12349 unique sequences.
# Sample 84 - 37852 reads in 20929 unique sequences.
# Sample 85 - 38268 reads in 19866 unique sequences.
# Sample 86 - 40183 reads in 18800 unique sequences.
# Sample 87 - 38631 reads in 19828 unique sequences.
# Sample 88 - 44924 reads in 21827 unique sequences.
# Sample 89 - 36046 reads in 18359 unique sequences.
# Sample 90 - 19883 reads in 7988 unique sequences.
# Sample 91 - 20451 reads in 10674 unique sequences.
# Sample 92 - 29434 reads in 14853 unique sequences.
# Sample 93 - 21617 reads in 10474 unique sequences.
# Sample 94 - 20020 reads in 9504 unique sequences.
# Sample 95 - 25035 reads in 12737 unique sequences.
# Sample 96 - 23820 reads in 12941 unique sequences.
# Sample 97 - 26760 reads in 13998 unique sequences.
# Sample 98 - 25050 reads in 13846 unique sequences.
# Sample 99 - 25365 reads in 12631 unique sequences.
# Sample 100 - 28964 reads in 13811 unique sequences.
# Sample 101 - 30636 reads in 15331 unique sequences.
# Sample 102 - 27451 reads in 13218 unique sequences.
# Sample 103 - 28275 reads in 14375 unique sequences.
# Sample 104 - 27166 reads in 13229 unique sequences.
# Sample 105 - 25043 reads in 12341 unique sequences.
# Sample 106 - 21342 reads in 10586 unique sequences.
# Sample 107 - 25957 reads in 12500 unique sequences.
# Sample 108 - 25133 reads in 10290 unique sequences.
# Sample 109 - 21104 reads in 11437 unique sequences.
# Sample 110 - 25628 reads in 12054 unique sequences.
# Sample 111 - 22242 reads in 11954 unique sequences.
# Sample 112 - 39169 reads in 20091 unique sequences.
# Sample 113 - 43939 reads in 22599 unique sequences.
# Sample 114 - 17789 reads in 10068 unique sequences.
# Sample 115 - 41772 reads in 21454 unique sequences.
# Sample 116 - 46747 reads in 23592 unique sequences.
# Sample 117 - 40568 reads in 18830 unique sequences.
# Sample 118 - 41590 reads in 21117 unique sequences.
# Sample 119 - 38575 reads in 18465 unique sequences.
# Sample 120 - 22705 reads in 9625 unique sequences.
# Sample 121 - 24261 reads in 12639 unique sequences.
# Sample 122 - 24656 reads in 11818 unique sequences.
# Sample 123 - 13295 reads in 7402 unique sequences.
# Sample 124 - 28 reads in 28 unique sequences.
# Sample 125 - 35951 reads in 20090 unique sequences.
# Sample 126 - 23356 reads in 13576 unique sequences.
# Sample 127 - 44972 reads in 22397 unique sequences.
# Sample 128 - 43551 reads in 22416 unique sequences.
# Sample 129 - 1429 reads in 1067 unique sequences.
# Sample 130 - 19585 reads in 9386 unique sequences.
# Sample 131 - 22985 reads in 11700 unique sequences.
# Sample 132 - 28844 reads in 13620 unique sequences.
# Sample 133 - 21571 reads in 10407 unique sequences.
# Sample 134 - 23291 reads in 11424 unique sequences.
# Sample 135 - 20133 reads in 10249 unique sequences.
# Sample 136 - 33587 reads in 18581 unique sequences.
# Sample 137 - 25091 reads in 13018 unique sequences.
# Sample 138 - 39305 reads in 18870 unique sequences.
# Sample 139 - 45125 reads in 21162 unique sequences.
# Sample 140 - 25720 reads in 13625 unique sequences.
# Sample 141 - 28813 reads in 12100 unique sequences.
# Sample 142 - 25667 reads in 12928 unique sequences.
# Sample 143 - 23747 reads in 11590 unique sequences.
# Sample 144 - 24946 reads in 12622 unique sequences.
# Sample 145 - 26880 reads in 12600 unique sequences.
# Sample 146 - 28661 reads in 14246 unique sequences.
# Sample 147 - 30697 reads in 14797 unique sequences.
# Sample 148 - 22796 reads in 11815 unique sequences.
# Sample 149 - 26875 reads in 12512 unique sequences.
# Sample 150 - 24514 reads in 9704 unique sequences.
# Sample 151 - 22220 reads in 11113 unique sequences.
# Sample 152 - 26932 reads in 12332 unique sequences.
# Sample 153 - 22665 reads in 10219 unique sequences.
# Sample 154 - 20820 reads in 10137 unique sequences.
# Sample 155 - 40733 reads in 20375 unique sequences.
# Sample 156 - 39123 reads in 21292 unique sequences.
# Sample 157 - 37073 reads in 18067 unique sequences.
# Sample 158 - 38820 reads in 21839 unique sequences.
# Sample 159 - 22199 reads in 12001 unique sequences.
# Sample 160 - 40512 reads in 20768 unique sequences.
# Sample 161 - 25312 reads in 12282 unique sequences.
# Sample 162 - 26974 reads in 13640 unique sequences.
# Sample 163 - 21330 reads in 11607 unique sequences.
# Sample 164 - 26200 reads in 13784 unique sequences.
# Sample 165 - 26004 reads in 13714 unique sequences.
# Sample 166 - 36073 reads in 18028 unique sequences.
# Sample 167 - 24696 reads in 13383 unique sequences.
# Sample 168 - 28014 reads in 14520 unique sequences.
# Sample 169 - 26500 reads in 13613 unique sequences.
# Sample 170 - 20522 reads in 11132 unique sequences.
# Sample 171 - 31436 reads in 15405 unique sequences.
# Sample 172 - 20175 reads in 8966 unique sequences.
# Sample 173 - 21050 reads in 11160 unique sequences.
# Sample 174 - 21652 reads in 10074 unique sequences.
# Sample 175 - 20702 reads in 10531 unique sequences.
# Sample 176 - 44995 reads in 23675 unique sequences.
# Sample 177 - 29867 reads in 16337 unique sequences.
# Sample 178 - 21440 reads in 12733 unique sequences.
# Sample 179 - 35823 reads in 19874 unique sequences.
# Sample 180 - 35860 reads in 17826 unique sequences.
# Sample 181 - 25364 reads in 10821 unique sequences.
# Sample 182 - 21733 reads in 10608 unique sequences.
# Sample 183 - 23500 reads in 10721 unique sequences.
# Sample 184 - 3425 reads in 2326 unique sequences.
# Sample 185 - 40844 reads in 20069 unique sequences.
# Sample 186 - 33084 reads in 16073 unique sequences.
# Sample 187 - 25783 reads in 13385 unique sequences.
# Sample 188 - 42020 reads in 21092 unique sequences.
# Sample 189 - 34832 reads in 16678 unique sequences.
# Sample 190 - 42711 reads in 20008 unique sequences.
# Sample 191 - 7968 reads in 4823 unique sequences.
# Sample 192 - 38273 reads in 19437 unique sequences.
# Sample 193 - 32274 reads in 16698 unique sequences.
# Sample 194 - 21766 reads in 12425 unique sequences.
# Sample 195 - 22431 reads in 8964 unique sequences.
# Sample 196 - 26905 reads in 13959 unique sequences.
# Sample 197 - 23224 reads in 13000 unique sequences.
# Sample 198 - 23252 reads in 12081 unique sequences.
# Sample 199 - 2169 reads in 971 unique sequences.
# Sample 200 - 44099 reads in 22535 unique sequences.
# Sample 201 - 23617 reads in 13707 unique sequences.
# Sample 202 - 23974 reads in 14092 unique sequences.
# Sample 203 - 22914 reads in 12886 unique sequences.
# Sample 204 - 22972 reads in 11876 unique sequences.
# Sample 205 - 26034 reads in 12634 unique sequences.
# Sample 206 - 24446 reads in 13480 unique sequences.
# Sample 207 - 18542 reads in 9317 unique sequences.
# Sample 208 - 26192 reads in 14414 unique sequences.
# Sample 209 - 29155 reads in 13950 unique sequences.
# Sample 210 - 24943 reads in 12468 unique sequences.
# Sample 211 - 22012 reads in 11504 unique sequences.
# Sample 212 - 17254 reads in 6813 unique sequences.
# Sample 213 - 25170 reads in 12185 unique sequences.
# Sample 214 - 25582 reads in 11231 unique sequences.
# Sample 215 - 25317 reads in 12396 unique sequences.
# Sample 216 - 19720 reads in 10484 unique sequences.
# Sample 217 - 19699 reads in 9457 unique sequences.
# Sample 218 - 24611 reads in 12015 unique sequences.
# Sample 219 - 19838 reads in 11613 unique sequences.
# Sample 220 - 25735 reads in 14196 unique sequences.
# Sample 221 - 23071 reads in 12249 unique sequences.
# Sample 222 - 27200 reads in 13758 unique sequences.
# Sample 223 - 27459 reads in 12955 unique sequences.
# Sample 224 - 20995 reads in 10649 unique sequences.
# Sample 225 - 18963 reads in 10608 unique sequences.
# Sample 226 - 22824 reads in 12322 unique sequences.
# Sample 227 - 20991 reads in 11654 unique sequences.
# Sample 228 - 20530 reads in 10403 unique sequences.
# Sample 229 - 18654 reads in 9617 unique sequences.
# Sample 230 - 18712 reads in 10302 unique sequences.
# Sample 231 - 11194 reads in 5687 unique sequences.
# Sample 232 - 20847 reads in 11113 unique sequences.
# Sample 233 - 23245 reads in 10657 unique sequences.
# Sample 234 - 22007 reads in 11170 unique sequences.
# Sample 235 - 39499 reads in 21578 unique sequences.
# Sample 236 - 20221 reads in 11762 unique sequences.
# Sample 237 - 37121 reads in 20827 unique sequences.
# Sample 238 - 41703 reads in 21157 unique sequences.
# Sample 239 - 20805 reads in 8694 unique sequences.
# Sample 240 - 22857 reads in 11457 unique sequences.
# Sample 241 - 20409 reads in 9452 unique sequences.
# Sample 242 - 23781 reads in 11843 unique sequences.
# Sample 243 - 36710 reads in 20298 unique sequences.
# Sample 244 - 42462 reads in 22023 unique sequences.
# Sample 245 - 21982 reads in 12572 unique sequences.
# Sample 246 - 45666 reads in 24420 unique sequences.
# Sample 247 - 35612 reads in 20144 unique sequences.
# Sample 248 - 23251 reads in 9720 unique sequences.
# Sample 249 - 23483 reads in 11567 unique sequences.
# Sample 250 - 21199 reads in 10188 unique sequences.
# Sample 251 - 20442 reads in 10235 unique sequences.
# Sample 252 - 40981 reads in 20911 unique sequences.
# Sample 253 - 38711 reads in 18748 unique sequences.
# Sample 254 - 39210 reads in 21385 unique sequences.
# Sample 255 - 24130 reads in 13127 unique sequences.
# Sample 256 - 40914 reads in 20442 unique sequences.
# Sample 257 - 41179 reads in 18899 unique sequences.
# Sample 258 - 40402 reads in 20183 unique sequences.
# Sample 259 - 39267 reads in 18851 unique sequences.
# Sample 1 - 25711 reads in 6515 unique sequences.
# Sample 2 - 20402 reads in 7909 unique sequences.
# Sample 3 - 21412 reads in 7055 unique sequences.
# Sample 4 - 18693 reads in 6502 unique sequences.
# Sample 5 - 42664 reads in 16975 unique sequences.
# Sample 6 - 41697 reads in 16498 unique sequences.
# Sample 7 - 18062 reads in 8576 unique sequences.
# Sample 8 - 38713 reads in 14520 unique sequences.
# Sample 9 - 39967 reads in 15032 unique sequences.
# Sample 10 - 47249 reads in 19033 unique sequences.
# Sample 11 - 42551 reads in 17660 unique sequences.
# Sample 12 - 24232 reads in 8834 unique sequences.
# Sample 13 - 22848 reads in 7670 unique sequences.
# Sample 14 - 22982 reads in 7608 unique sequences.
# Sample 15 - 51530 reads in 19273 unique sequences.
# Sample 16 - 16 reads in 14 unique sequences.
# Sample 17 - 40261 reads in 15667 unique sequences.
# Sample 18 - 19352 reads in 7636 unique sequences.
# Sample 19 - 45853 reads in 19376 unique sequences.
# Sample 20 - 40695 reads in 15411 unique sequences.
# Sample 21 - 44818 reads in 17846 unique sequences.
# Sample 22 - 40718 reads in 16688 unique sequences.
# Sample 23 - 6 reads in 5 unique sequences.
# Sample 24 - 22918 reads in 9077 unique sequences.
# Sample 25 - 20676 reads in 7717 unique sequences.
# Sample 26 - 23177 reads in 8496 unique sequences.
# Sample 27 - 39587 reads in 12176 unique sequences.
# Sample 28 - 21180 reads in 9073 unique sequences.
# Sample 29 - 38137 reads in 17823 unique sequences.
# Sample 30 - 34482 reads in 14549 unique sequences.
# Sample 31 - 40928 reads in 15454 unique sequences.
# Sample 32 - 42095 reads in 16944 unique sequences.
# Sample 33 - 38174 reads in 16000 unique sequences.
# Sample 34 - 39066 reads in 14429 unique sequences.
# Sample 35 - 25862 reads in 10584 unique sequences.
# Sample 36 - 20398 reads in 8453 unique sequences.
# Sample 37 - 20587 reads in 8697 unique sequences.
# Sample 38 - 21419 reads in 9813 unique sequences.
# Sample 39 - 21806 reads in 10874 unique sequences.
# Sample 40 - 18213 reads in 8329 unique sequences.
# Sample 41 - 23917 reads in 9432 unique sequences.
# Sample 42 - 29447 reads in 11909 unique sequences.
# Sample 43 - 23241 reads in 10588 unique sequences.
# Sample 44 - 24795 reads in 10725 unique sequences.
# Sample 45 - 20133 reads in 9151 unique sequences.
# Sample 46 - 25652 reads in 10586 unique sequences.
# Sample 47 - 15295 reads in 6780 unique sequences.
# Sample 48 - 28151 reads in 8569 unique sequences.
# Sample 49 - 24003 reads in 8744 unique sequences.
# Sample 50 - 23634 reads in 6876 unique sequences.
# Sample 51 - 22224 reads in 8072 unique sequences.
# Sample 52 - 27605 reads in 9373 unique sequences.
# Sample 53 - 22441 reads in 7450 unique sequences.
# Sample 54 - 31418 reads in 13442 unique sequences.
# Sample 55 - 78162 reads in 24573 unique sequences.
# Sample 56 - 23810 reads in 10515 unique sequences.
# Sample 57 - 43776 reads in 16695 unique sequences.
# Sample 58 - 39610 reads in 16293 unique sequences.
# Sample 59 - 21724 reads in 6202 unique sequences.
# Sample 60 - 25236 reads in 9379 unique sequences.
# Sample 61 - 23302 reads in 8603 unique sequences.
# Sample 62 - 22932 reads in 8036 unique sequences.
# Sample 63 - 37572 reads in 15615 unique sequences.
# Sample 64 - 41987 reads in 18079 unique sequences.
# Sample 65 - 25035 reads in 11297 unique sequences.
# Sample 66 - 38663 reads in 16164 unique sequences.
# Sample 67 - 37800 reads in 15853 unique sequences.
# Sample 68 - 16188 reads in 5639 unique sequences.
# Sample 69 - 21522 reads in 8207 unique sequences.
# Sample 70 - 23239 reads in 5780 unique sequences.
# Sample 71 - 26292 reads in 7666 unique sequences.
# Sample 72 - 37909 reads in 15370 unique sequences.
# Sample 73 - 40226 reads in 14032 unique sequences.
# Sample 74 - 22806 reads in 8699 unique sequences.
# Sample 75 - 43415 reads in 17291 unique sequences.
# Sample 76 - 41346 reads in 15241 unique sequences.
# Sample 77 - 17200 reads in 5804 unique sequences.
# Sample 78 - 22427 reads in 8337 unique sequences.
# Sample 79 - 22271 reads in 7620 unique sequences.
# Sample 80 - 37846 reads in 14934 unique sequences.
# Sample 81 - 43086 reads in 16266 unique sequences.
# Sample 82 - 52 reads in 46 unique sequences.
# Sample 83 - 21431 reads in 9390 unique sequences.
# Sample 84 - 37852 reads in 16287 unique sequences.
# Sample 85 - 38268 reads in 15705 unique sequences.
# Sample 86 - 40183 reads in 15883 unique sequences.
# Sample 87 - 38631 reads in 17166 unique sequences.
# Sample 88 - 44924 reads in 18274 unique sequences.
# Sample 89 - 36046 reads in 14631 unique sequences.
# Sample 90 - 19883 reads in 5846 unique sequences.
# Sample 91 - 20451 reads in 7757 unique sequences.
# Sample 92 - 29434 reads in 11394 unique sequences.
# Sample 93 - 21617 reads in 7922 unique sequences.
# Sample 94 - 20020 reads in 6548 unique sequences.
# Sample 95 - 25035 reads in 9371 unique sequences.
# Sample 96 - 23820 reads in 10326 unique sequences.
# Sample 97 - 26760 reads in 11194 unique sequences.
# Sample 98 - 25050 reads in 10793 unique sequences.
# Sample 99 - 25365 reads in 10443 unique sequences.
# Sample 100 - 28964 reads in 11307 unique sequences.
# Sample 101 - 30636 reads in 12259 unique sequences.
# Sample 102 - 27451 reads in 10401 unique sequences.
# Sample 103 - 28275 reads in 11428 unique sequences.
# Sample 104 - 27166 reads in 10297 unique sequences.
# Sample 105 - 25043 reads in 10062 unique sequences.
# Sample 106 - 21342 reads in 8843 unique sequences.
# Sample 107 - 25957 reads in 9567 unique sequences.
# Sample 108 - 25133 reads in 7621 unique sequences.
# Sample 109 - 21104 reads in 8458 unique sequences.
# Sample 110 - 25628 reads in 9026 unique sequences.
# Sample 111 - 22242 reads in 8921 unique sequences.
# Sample 112 - 39169 reads in 16212 unique sequences.
# Sample 113 - 43939 reads in 16941 unique sequences.
# Sample 114 - 17789 reads in 7319 unique sequences.
# Sample 115 - 41772 reads in 17024 unique sequences.
# Sample 116 - 46747 reads in 18475 unique sequences.
# Sample 117 - 40568 reads in 15191 unique sequences.
# Sample 118 - 41590 reads in 16888 unique sequences.
# Sample 119 - 38575 reads in 14835 unique sequences.
# Sample 120 - 22705 reads in 7549 unique sequences.
# Sample 121 - 24261 reads in 9787 unique sequences.
# Sample 122 - 24656 reads in 9812 unique sequences.
# Sample 123 - 13295 reads in 6146 unique sequences.
# Sample 124 - 28 reads in 27 unique sequences.
# Sample 125 - 35951 reads in 16167 unique sequences.
# Sample 126 - 23356 reads in 10591 unique sequences.
# Sample 127 - 44972 reads in 17420 unique sequences.
# Sample 128 - 43551 reads in 17823 unique sequences.
# Sample 129 - 1429 reads in 926 unique sequences.
# Sample 130 - 19585 reads in 7000 unique sequences.
# Sample 131 - 22985 reads in 8804 unique sequences.
# Sample 132 - 28844 reads in 10725 unique sequences.
# Sample 133 - 21571 reads in 7984 unique sequences.
# Sample 134 - 23291 reads in 8495 unique sequences.
# Sample 135 - 20133 reads in 8317 unique sequences.
# Sample 136 - 33587 reads in 14858 unique sequences.
# Sample 137 - 25091 reads in 10057 unique sequences.
# Sample 138 - 39305 reads in 14766 unique sequences.
# Sample 139 - 45125 reads in 17883 unique sequences.
# Sample 140 - 25720 reads in 10613 unique sequences.
# Sample 141 - 28813 reads in 10600 unique sequences.
# Sample 142 - 25667 reads in 10326 unique sequences.
# Sample 143 - 23747 reads in 8979 unique sequences.
# Sample 144 - 24946 reads in 10003 unique sequences.
# Sample 145 - 26880 reads in 10121 unique sequences.
# Sample 146 - 28661 reads in 11377 unique sequences.
# Sample 147 - 30697 reads in 11324 unique sequences.
# Sample 148 - 22796 reads in 9964 unique sequences.
# Sample 149 - 26875 reads in 9473 unique sequences.
# Sample 150 - 24514 reads in 7430 unique sequences.
# Sample 151 - 22220 reads in 8589 unique sequences.
# Sample 152 - 26932 reads in 9560 unique sequences.
# Sample 153 - 22665 reads in 7987 unique sequences.
# Sample 154 - 20820 reads in 7816 unique sequences.
# Sample 155 - 40733 reads in 16388 unique sequences.
# Sample 156 - 39123 reads in 16043 unique sequences.
# Sample 157 - 37073 reads in 14403 unique sequences.
# Sample 158 - 38820 reads in 16755 unique sequences.
# Sample 159 - 22199 reads in 9074 unique sequences.
# Sample 160 - 40512 reads in 16499 unique sequences.
# Sample 161 - 25312 reads in 9867 unique sequences.
# Sample 162 - 26974 reads in 11167 unique sequences.
# Sample 163 - 21330 reads in 9649 unique sequences.
# Sample 164 - 26200 reads in 11408 unique sequences.
# Sample 165 - 26004 reads in 10517 unique sequences.
# Sample 166 - 36073 reads in 14991 unique sequences.
# Sample 167 - 24696 reads in 10672 unique sequences.
# Sample 168 - 28014 reads in 11613 unique sequences.
# Sample 169 - 26500 reads in 10899 unique sequences.
# Sample 170 - 20522 reads in 8992 unique sequences.
# Sample 171 - 31436 reads in 12350 unique sequences.
# Sample 172 - 20175 reads in 6539 unique sequences.
# Sample 173 - 21050 reads in 8321 unique sequences.
# Sample 174 - 21652 reads in 7817 unique sequences.
# Sample 175 - 20702 reads in 8165 unique sequences.
# Sample 176 - 44995 reads in 18653 unique sequences.
# Sample 177 - 29867 reads in 14616 unique sequences.
# Sample 178 - 21440 reads in 10337 unique sequences.
# Sample 179 - 35823 reads in 16285 unique sequences.
# Sample 180 - 35860 reads in 14814 unique sequences.
# Sample 181 - 25364 reads in 8303 unique sequences.
# Sample 182 - 21733 reads in 8120 unique sequences.
# Sample 183 - 23500 reads in 8444 unique sequences.
# Sample 184 - 3425 reads in 2228 unique sequences.
# Sample 185 - 40844 reads in 16754 unique sequences.
# Sample 186 - 33084 reads in 12561 unique sequences.
# Sample 187 - 25783 reads in 10313 unique sequences.
# Sample 188 - 42020 reads in 17239 unique sequences.
# Sample 189 - 34832 reads in 14224 unique sequences.
# Sample 190 - 42711 reads in 17084 unique sequences.
# Sample 191 - 7968 reads in 5297 unique sequences.
# Sample 192 - 38273 reads in 16806 unique sequences.
# Sample 193 - 32274 reads in 12896 unique sequences.
# Sample 194 - 21766 reads in 9331 unique sequences.
# Sample 195 - 22431 reads in 6105 unique sequences.
# Sample 196 - 26905 reads in 10612 unique sequences.
# Sample 197 - 23224 reads in 10433 unique sequences.
# Sample 198 - 23252 reads in 9230 unique sequences.
# Sample 199 - 2169 reads in 896 unique sequences.
# Sample 200 - 44099 reads in 18606 unique sequences.
# Sample 201 - 23617 reads in 10627 unique sequences.
# Sample 202 - 23974 reads in 10709 unique sequences.
# Sample 203 - 22914 reads in 10255 unique sequences.
# Sample 204 - 22972 reads in 9307 unique sequences.
# Sample 205 - 26034 reads in 10200 unique sequences.
# Sample 206 - 24446 reads in 10876 unique sequences.
# Sample 207 - 18542 reads in 7418 unique sequences.
# Sample 208 - 26192 reads in 11229 unique sequences.
# Sample 209 - 29155 reads in 11329 unique sequences.
# Sample 210 - 24943 reads in 10277 unique sequences.
# Sample 211 - 22012 reads in 9525 unique sequences.
# Sample 212 - 17254 reads in 5361 unique sequences.
# Sample 213 - 25170 reads in 10229 unique sequences.
# Sample 214 - 25582 reads in 8032 unique sequences.
# Sample 215 - 25317 reads in 8699 unique sequences.
# Sample 216 - 19720 reads in 8047 unique sequences.
# Sample 217 - 19699 reads in 7507 unique sequences.
# Sample 218 - 24611 reads in 10213 unique sequences.
# Sample 219 - 19838 reads in 9506 unique sequences.
# Sample 220 - 25735 reads in 10837 unique sequences.
# Sample 221 - 23071 reads in 9605 unique sequences.
# Sample 222 - 27200 reads in 11488 unique sequences.
# Sample 223 - 27459 reads in 10566 unique sequences.
# Sample 224 - 20995 reads in 9030 unique sequences.
# Sample 225 - 18963 reads in 8717 unique sequences.
# Sample 226 - 22824 reads in 9604 unique sequences.
# Sample 227 - 20991 reads in 9249 unique sequences.
# Sample 228 - 20530 reads in 8121 unique sequences.
# Sample 229 - 18654 reads in 7822 unique sequences.
# Sample 230 - 18712 reads in 7913 unique sequences.
# Sample 231 - 11194 reads in 4113 unique sequences.
# Sample 232 - 20847 reads in 8356 unique sequences.
# Sample 233 - 23245 reads in 8474 unique sequences.
# Sample 234 - 22007 reads in 8494 unique sequences.
# Sample 235 - 39499 reads in 17095 unique sequences.
# Sample 236 - 20221 reads in 9347 unique sequences.
# Sample 237 - 37121 reads in 16234 unique sequences.
# Sample 238 - 41703 reads in 17159 unique sequences.
# Sample 239 - 20805 reads in 6634 unique sequences.
# Sample 240 - 22857 reads in 8818 unique sequences.
# Sample 241 - 20409 reads in 7154 unique sequences.
# Sample 242 - 23781 reads in 9099 unique sequences.
# Sample 243 - 36710 reads in 15843 unique sequences.
# Sample 244 - 42462 reads in 18699 unique sequences.
# Sample 245 - 21982 reads in 9379 unique sequences.
# Sample 246 - 45666 reads in 19712 unique sequences.
# Sample 247 - 35612 reads in 16150 unique sequences.
# Sample 248 - 23251 reads in 6888 unique sequences.
# Sample 249 - 23483 reads in 8597 unique sequences.
# Sample 250 - 21199 reads in 8011 unique sequences.
# Sample 251 - 20442 reads in 7695 unique sequences.
# Sample 252 - 40981 reads in 16544 unique sequences.
# Sample 253 - 38711 reads in 16115 unique sequences.
# Sample 254 - 39210 reads in 16110 unique sequences.
# Sample 255 - 24130 reads in 10223 unique sequences.
# Sample 256 - 40914 reads in 17230 unique sequences.
# Sample 257 - 41179 reads in 16384 unique sequences.
# Sample 258 - 40402 reads in 15891 unique sequences.
# Sample 259 - 39267 reads in 15843 unique sequences.

# %%
# Merge paired reads 
mergers <- mergePairs(dadaFs, derepFs, dadaRs, derepRs, verbose=TRUE)

# Back up generated object 
save(mergers, file="output/2_dada2/objects/mergers.RData")
# Out:
# 20673 paired-reads (in 776 unique pairings) successfully merged out of 23905 (in 2925 pairings) input.
# 12067 paired-reads (in 577 unique pairings) successfully merged out of 17082 (in 3906 pairings) input.
# 14644 paired-reads (in 693 unique pairings) successfully merged out of 18786 (in 3442 pairings) input.
# 12356 paired-reads (in 549 unique pairings) successfully merged out of 16086 (in 3054 pairings) input.
# 27032 paired-reads (in 1129 unique pairings) successfully merged out of 37110 (in 7969 pairings) input.
# 27274 paired-reads (in 1213 unique pairings) successfully merged out of 36450 (in 7165 pairings) input.
# 9906 paired-reads (in 513 unique pairings) successfully merged out of 14484 (in 3661 pairings) input.
# 23642 paired-reads (in 909 unique pairings) successfully merged out of 32945 (in 6921 pairings) input.
# 28311 paired-reads (in 1368 unique pairings) successfully merged out of 35568 (in 5935 pairings) input.
# 28507 paired-reads (in 1263 unique pairings) successfully merged out of 39919 (in 9210 pairings) input.
# 26861 paired-reads (in 1074 unique pairings) successfully merged out of 35975 (in 7237 pairings) input.
# 15831 paired-reads (in 623 unique pairings) successfully merged out of 20833 (in 4016 pairings) input.
# 15562 paired-reads (in 783 unique pairings) successfully merged out of 19867 (in 3669 pairings) input.
# 15301 paired-reads (in 681 unique pairings) successfully merged out of 20002 (in 3818 pairings) input.
# 32087 paired-reads (in 1472 unique pairings) successfully merged out of 44834 (in 10043 pairings) input.
# 4 paired-reads (in 1 unique pairings) successfully merged out of 4 (in 1 pairings) input.
# 25931 paired-reads (in 1120 unique pairings) successfully merged out of 34811 (in 6837 pairings) input.
# 12088 paired-reads (in 611 unique pairings) successfully merged out of 16215 (in 3440 pairings) input.
# 27403 paired-reads (in 1266 unique pairings) successfully merged out of 39237 (in 9368 pairings) input.
# 25155 paired-reads (in 1023 unique pairings) successfully merged out of 34712 (in 7495 pairings) input.
# 27920 paired-reads (in 1161 unique pairings) successfully merged out of 37918 (in 8077 pairings) input.
# 24472 paired-reads (in 1228 unique pairings) successfully merged out of 34481 (in 8473 pairings) input.
# 2 paired-reads (in 1 unique pairings) successfully merged out of 2 (in 1 pairings) input.
# 14007 paired-reads (in 657 unique pairings) successfully merged out of 19193 (in 4289 pairings) input.
# 13013 paired-reads (in 642 unique pairings) successfully merged out of 17559 (in 3649 pairings) input.
# 15200 paired-reads (in 686 unique pairings) successfully merged out of 19923 (in 3994 pairings) input.
# 30870 paired-reads (in 1111 unique pairings) successfully merged out of 36414 (in 4025 pairings) input.
# 11568 paired-reads (in 570 unique pairings) successfully merged out of 17173 (in 4408 pairings) input.
# 21378 paired-reads (in 874 unique pairings) successfully merged out of 31500 (in 7536 pairings) input.
# 19776 paired-reads (in 929 unique pairings) successfully merged out of 28725 (in 7244 pairings) input.
# 26161 paired-reads (in 1178 unique pairings) successfully merged out of 35186 (in 7457 pairings) input.
# 25669 paired-reads (in 1126 unique pairings) successfully merged out of 35454 (in 7665 pairings) input.
# 21926 paired-reads (in 1047 unique pairings) successfully merged out of 31828 (in 7859 pairings) input.
# 25832 paired-reads (in 1052 unique pairings) successfully merged out of 33893 (in 6605 pairings) input.
# 15438 paired-reads (in 785 unique pairings) successfully merged out of 21790 (in 5330 pairings) input.
# 11793 paired-reads (in 629 unique pairings) successfully merged out of 16705 (in 3945 pairings) input.
# 11499 paired-reads (in 637 unique pairings) successfully merged out of 16849 (in 4325 pairings) input.
# 11585 paired-reads (in 583 unique pairings) successfully merged out of 17225 (in 4472 pairings) input.
# 11198 paired-reads (in 601 unique pairings) successfully merged out of 17144 (in 4473 pairings) input.
# 10298 paired-reads (in 442 unique pairings) successfully merged out of 14704 (in 3337 pairings) input.
# 14850 paired-reads (in 681 unique pairings) successfully merged out of 20220 (in 4452 pairings) input.
# 17319 paired-reads (in 788 unique pairings) successfully merged out of 24094 (in 5591 pairings) input.
# 12875 paired-reads (in 613 unique pairings) successfully merged out of 18801 (in 4612 pairings) input.
# 13810 paired-reads (in 775 unique pairings) successfully merged out of 20042 (in 5187 pairings) input.
# 10951 paired-reads (in 511 unique pairings) successfully merged out of 16095 (in 4162 pairings) input.
# 15005 paired-reads (in 725 unique pairings) successfully merged out of 21123 (in 4882 pairings) input.
# 8408 paired-reads (in 430 unique pairings) successfully merged out of 12023 (in 2946 pairings) input.
# 20896 paired-reads (in 687 unique pairings) successfully merged out of 25269 (in 3680 pairings) input.
# 16232 paired-reads (in 616 unique pairings) successfully merged out of 20890 (in 3530 pairings) input.
# 17014 paired-reads (in 756 unique pairings) successfully merged out of 20973 (in 3336 pairings) input.
# 13699 paired-reads (in 604 unique pairings) successfully merged out of 18748 (in 4176 pairings) input.
# 18274 paired-reads (in 901 unique pairings) successfully merged out of 24291 (in 4861 pairings) input.
# 15100 paired-reads (in 670 unique pairings) successfully merged out of 19463 (in 3567 pairings) input.
# 18411 paired-reads (in 868 unique pairings) successfully merged out of 26691 (in 6377 pairings) input.
# 54804 paired-reads (in 1677 unique pairings) successfully merged out of 71069 (in 12324 pairings) input.
# 13674 paired-reads (in 639 unique pairings) successfully merged out of 19377 (in 4469 pairings) input.
# 29287 paired-reads (in 1242 unique pairings) successfully merged out of 38196 (in 6998 pairings) input.
# 24607 paired-reads (in 1062 unique pairings) successfully merged out of 33842 (in 7434 pairings) input.
# 15760 paired-reads (in 732 unique pairings) successfully merged out of 19344 (in 3139 pairings) input.
# 15735 paired-reads (in 744 unique pairings) successfully merged out of 21534 (in 4709 pairings) input.
# 14575 paired-reads (in 748 unique pairings) successfully merged out of 19979 (in 4428 pairings) input.
# 14554 paired-reads (in 667 unique pairings) successfully merged out of 19702 (in 4119 pairings) input.
# 21584 paired-reads (in 965 unique pairings) successfully merged out of 31572 (in 7769 pairings) input.
# 26270 paired-reads (in 1053 unique pairings) successfully merged out of 35967 (in 7533 pairings) input.
# 13301 paired-reads (in 597 unique pairings) successfully merged out of 19883 (in 4787 pairings) input.
# 23202 paired-reads (in 1024 unique pairings) successfully merged out of 32774 (in 7750 pairings) input.
# 22251 paired-reads (in 1075 unique pairings) successfully merged out of 31568 (in 7631 pairings) input.
# 11066 paired-reads (in 397 unique pairings) successfully merged out of 13844 (in 2292 pairings) input.
# 13404 paired-reads (in 654 unique pairings) successfully merged out of 18132 (in 3944 pairings) input.
# 19148 paired-reads (in 604 unique pairings) successfully merged out of 21551 (in 2002 pairings) input.
# 20685 paired-reads (in 661 unique pairings) successfully merged out of 24308 (in 2600 pairings) input.
# 23532 paired-reads (in 977 unique pairings) successfully merged out of 32966 (in 7045 pairings) input.
# 27887 paired-reads (in 1006 unique pairings) successfully merged out of 36260 (in 5960 pairings) input.
# 14711 paired-reads (in 608 unique pairings) successfully merged out of 19065 (in 3540 pairings) input.
# 28042 paired-reads (in 1049 unique pairings) successfully merged out of 37622 (in 7078 pairings) input.
# 27403 paired-reads (in 1143 unique pairings) successfully merged out of 36201 (in 6820 pairings) input.
# 12429 paired-reads (in 409 unique pairings) successfully merged out of 15119 (in 2177 pairings) input.
# 14324 paired-reads (in 638 unique pairings) successfully merged out of 19012 (in 3898 pairings) input.
# 15068 paired-reads (in 729 unique pairings) successfully merged out of 19453 (in 3741 pairings) input.
# 23247 paired-reads (in 1004 unique pairings) successfully merged out of 32713 (in 7153 pairings) input.
# 27848 paired-reads (in 1313 unique pairings) successfully merged out of 37374 (in 7720 pairings) input.
# 9 paired-reads (in 2 unique pairings) successfully merged out of 9 (in 2 pairings) input.
# 11300 paired-reads (in 566 unique pairings) successfully merged out of 17327 (in 4496 pairings) input.
# 20642 paired-reads (in 967 unique pairings) successfully merged out of 31455 (in 8256 pairings) input.
# 22462 paired-reads (in 1070 unique pairings) successfully merged out of 31959 (in 7621 pairings) input.
# 25623 paired-reads (in 1128 unique pairings) successfully merged out of 34710 (in 7436 pairings) input.
# 23152 paired-reads (in 1063 unique pairings) successfully merged out of 32414 (in 7556 pairings) input.
# 27351 paired-reads (in 1279 unique pairings) successfully merged out of 38196 (in 8721 pairings) input.
# 21580 paired-reads (in 968 unique pairings) successfully merged out of 30162 (in 6901 pairings) input.
# 15342 paired-reads (in 552 unique pairings) successfully merged out of 18009 (in 2266 pairings) input.
# 12268 paired-reads (in 640 unique pairings) successfully merged out of 17096 (in 3952 pairings) input.
# 18277 paired-reads (in 874 unique pairings) successfully merged out of 24837 (in 5288 pairings) input.
# 13591 paired-reads (in 696 unique pairings) successfully merged out of 18305 (in 3971 pairings) input.
# 12693 paired-reads (in 614 unique pairings) successfully merged out of 17319 (in 3788 pairings) input.
# 14970 paired-reads (in 699 unique pairings) successfully merged out of 21110 (in 4946 pairings) input.
# 13693 paired-reads (in 641 unique pairings) successfully merged out of 19406 (in 4464 pairings) input.
# 16260 paired-reads (in 739 unique pairings) successfully merged out of 22234 (in 4679 pairings) input.
# 14508 paired-reads (in 652 unique pairings) successfully merged out of 20214 (in 4528 pairings) input.
# 15759 paired-reads (in 753 unique pairings) successfully merged out of 21308 (in 4758 pairings) input.
# 18480 paired-reads (in 761 unique pairings) successfully merged out of 24757 (in 5126 pairings) input.
# 18748 paired-reads (in 854 unique pairings) successfully merged out of 25831 (in 5845 pairings) input.
# 17523 paired-reads (in 721 unique pairings) successfully merged out of 23228 (in 4526 pairings) input.
# 17064 paired-reads (in 815 unique pairings) successfully merged out of 23716 (in 5521 pairings) input.
# 16805 paired-reads (in 755 unique pairings) successfully merged out of 23057 (in 4960 pairings) input.
# 15358 paired-reads (in 739 unique pairings) successfully merged out of 21039 (in 4719 pairings) input.
# 13341 paired-reads (in 535 unique pairings) successfully merged out of 17745 (in 3423 pairings) input.
# 16045 paired-reads (in 768 unique pairings) successfully merged out of 22120 (in 4784 pairings) input.
# 17783 paired-reads (in 785 unique pairings) successfully merged out of 22549 (in 4037 pairings) input.
# 12288 paired-reads (in 620 unique pairings) successfully merged out of 17357 (in 4164 pairings) input.
# 16264 paired-reads (in 770 unique pairings) successfully merged out of 22098 (in 4674 pairings) input.
# 12656 paired-reads (in 608 unique pairings) successfully merged out of 18272 (in 4441 pairings) input.
# 23622 paired-reads (in 964 unique pairings) successfully merged out of 32929 (in 6923 pairings) input.
# 26792 paired-reads (in 1253 unique pairings) successfully merged out of 37996 (in 9027 pairings) input.
# 10486 paired-reads (in 499 unique pairings) successfully merged out of 14492 (in 3205 pairings) input.
# 24844 paired-reads (in 1112 unique pairings) successfully merged out of 35207 (in 8175 pairings) input.
# 28216 paired-reads (in 1262 unique pairings) successfully merged out of 39805 (in 9201 pairings) input.
# 26030 paired-reads (in 982 unique pairings) successfully merged out of 34756 (in 6654 pairings) input.
# 25160 paired-reads (in 1104 unique pairings) successfully merged out of 34998 (in 7875 pairings) input.
# 23980 paired-reads (in 1132 unique pairings) successfully merged out of 33435 (in 7430 pairings) input.
# 16564 paired-reads (in 578 unique pairings) successfully merged out of 20285 (in 3025 pairings) input.
# 14611 paired-reads (in 669 unique pairings) successfully merged out of 20255 (in 4575 pairings) input.
# 15261 paired-reads (in 709 unique pairings) successfully merged out of 21149 (in 4586 pairings) input.
# 7470 paired-reads (in 402 unique pairings) successfully merged out of 10964 (in 2682 pairings) input.
# No paired-reads (in ZERO unique pairings) successfully merged out of 28 pairings) input.
# 19889 paired-reads (in 913 unique pairings) successfully merged out of 30737 (in 8339 pairings) input.
# 12696 paired-reads (in 589 unique pairings) successfully merged out of 19165 (in 4650 pairings) input.
# 27428 paired-reads (in 1137 unique pairings) successfully merged out of 38946 (in 8509 pairings) input.
# 25850 paired-reads (in 1229 unique pairings) successfully merged out of 36692 (in 8977 pairings) input.
# 509 paired-reads (in 61 unique pairings) successfully merged out of 894 (in 226 pairings) input.
# 13133 paired-reads (in 468 unique pairings) successfully merged out of 16971 (in 3140 pairings) input.
# 14055 paired-reads (in 669 unique pairings) successfully merged out of 19251 (in 4232 pairings) input.
# 18932 paired-reads (in 1004 unique pairings) successfully merged out of 25195 (in 5280 pairings) input.
# 13305 paired-reads (in 757 unique pairings) successfully merged out of 18618 (in 4387 pairings) input.
# 14555 paired-reads (in 779 unique pairings) successfully merged out of 20126 (in 4676 pairings) input.
# 12345 paired-reads (in 612 unique pairings) successfully merged out of 16983 (in 3809 pairings) input.
# 19131 paired-reads (in 829 unique pairings) successfully merged out of 27495 (in 6268 pairings) input.
# 15490 paired-reads (in 673 unique pairings) successfully merged out of 21118 (in 4477 pairings) input.
# 24722 paired-reads (in 1165 unique pairings) successfully merged out of 34169 (in 7203 pairings) input.
# 28649 paired-reads (in 1361 unique pairings) successfully merged out of 38992 (in 8383 pairings) input.
# 15388 paired-reads (in 730 unique pairings) successfully merged out of 21535 (in 4974 pairings) input.
# 19910 paired-reads (in 752 unique pairings) successfully merged out of 25224 (in 3886 pairings) input.
# 15150 paired-reads (in 766 unique pairings) successfully merged out of 21502 (in 5013 pairings) input.
# 15168 paired-reads (in 716 unique pairings) successfully merged out of 20222 (in 4102 pairings) input.
# 15712 paired-reads (in 662 unique pairings) successfully merged out of 21130 (in 4298 pairings) input.
# 16971 paired-reads (in 829 unique pairings) successfully merged out of 23070 (in 4932 pairings) input.
# 17396 paired-reads (in 866 unique pairings) successfully merged out of 24385 (in 5715 pairings) input.
# 19273 paired-reads (in 970 unique pairings) successfully merged out of 26295 (in 6045 pairings) input.
# 13903 paired-reads (in 666 unique pairings) successfully merged out of 18910 (in 4065 pairings) input.
# 17271 paired-reads (in 902 unique pairings) successfully merged out of 23365 (in 4937 pairings) input.
# 18404 paired-reads (in 671 unique pairings) successfully merged out of 21805 (in 3058 pairings) input.
# 13814 paired-reads (in 707 unique pairings) successfully merged out of 18955 (in 4236 pairings) input.
# 17666 paired-reads (in 724 unique pairings) successfully merged out of 23124 (in 4409 pairings) input.
# 14925 paired-reads (in 703 unique pairings) successfully merged out of 19631 (in 4002 pairings) input.
# 12984 paired-reads (in 697 unique pairings) successfully merged out of 17989 (in 4002 pairings) input.
# 25017 paired-reads (in 1163 unique pairings) successfully merged out of 34370 (in 7438 pairings) input.
# 21759 paired-reads (in 1154 unique pairings) successfully merged out of 32604 (in 8418 pairings) input.
# 23739 paired-reads (in 961 unique pairings) successfully merged out of 31616 (in 6092 pairings) input.
# 21323 paired-reads (in 1056 unique pairings) successfully merged out of 32778 (in 9041 pairings) input.
# 13125 paired-reads (in 610 unique pairings) successfully merged out of 18230 (in 4077 pairings) input.
# 24438 paired-reads (in 1140 unique pairings) successfully merged out of 34774 (in 8486 pairings) input.
# 16101 paired-reads (in 666 unique pairings) successfully merged out of 20962 (in 3974 pairings) input.
# 16743 paired-reads (in 740 unique pairings) successfully merged out of 22540 (in 4796 pairings) input.
# 12261 paired-reads (in 661 unique pairings) successfully merged out of 17668 (in 4374 pairings) input.
# 15188 paired-reads (in 777 unique pairings) successfully merged out of 21652 (in 5416 pairings) input.
# 15108 paired-reads (in 737 unique pairings) successfully merged out of 21429 (in 5078 pairings) input.
# 21864 paired-reads (in 978 unique pairings) successfully merged out of 30769 (in 7078 pairings) input.
# 13710 paired-reads (in 716 unique pairings) successfully merged out of 19994 (in 5114 pairings) input.
# 16386 paired-reads (in 808 unique pairings) successfully merged out of 23555 (in 5848 pairings) input.
# 15834 paired-reads (in 774 unique pairings) successfully merged out of 22206 (in 5255 pairings) input.
# 11595 paired-reads (in 601 unique pairings) successfully merged out of 16695 (in 4050 pairings) input.
# 19264 paired-reads (in 866 unique pairings) successfully merged out of 26656 (in 6056 pairings) input.
# 14049 paired-reads (in 586 unique pairings) successfully merged out of 17579 (in 2952 pairings) input.
# 12430 paired-reads (in 594 unique pairings) successfully merged out of 17417 (in 4081 pairings) input.
# 14264 paired-reads (in 742 unique pairings) successfully merged out of 18755 (in 3890 pairings) input.
# 12450 paired-reads (in 649 unique pairings) successfully merged out of 17381 (in 4179 pairings) input.
# 26708 paired-reads (in 1131 unique pairings) successfully merged out of 37872 (in 8515 pairings) input.
# 17598 paired-reads (in 683 unique pairings) successfully merged out of 25146 (in 5483 pairings) input.
# 11560 paired-reads (in 564 unique pairings) successfully merged out of 17137 (in 4305 pairings) input.
# 20581 paired-reads (in 897 unique pairings) successfully merged out of 30209 (in 7283 pairings) input.
# 21998 paired-reads (in 941 unique pairings) successfully merged out of 30368 (in 6620 pairings) input.
# 17817 paired-reads (in 733 unique pairings) successfully merged out of 22612 (in 3804 pairings) input.
# 13922 paired-reads (in 667 unique pairings) successfully merged out of 18575 (in 3753 pairings) input.
# 15523 paired-reads (in 771 unique pairings) successfully merged out of 20348 (in 4078 pairings) input.
# 1617 paired-reads (in 114 unique pairings) successfully merged out of 2446 (in 568 pairings) input.
# 25351 paired-reads (in 1168 unique pairings) successfully merged out of 34579 (in 7548 pairings) input.
# 21781 paired-reads (in 822 unique pairings) successfully merged out of 28704 (in 5239 pairings) input.
# 15997 paired-reads (in 603 unique pairings) successfully merged out of 21743 (in 4303 pairings) input.
# 25468 paired-reads (in 1242 unique pairings) successfully merged out of 35920 (in 8556 pairings) input.
# 21391 paired-reads (in 987 unique pairings) successfully merged out of 29389 (in 6327 pairings) input.
# 27024 paired-reads (in 1105 unique pairings) successfully merged out of 36732 (in 7833 pairings) input.
# 3884 paired-reads (in 182 unique pairings) successfully merged out of 5893 (in 1322 pairings) input.
# 22409 paired-reads (in 1208 unique pairings) successfully merged out of 31920 (in 8008 pairings) input.
# 19347 paired-reads (in 944 unique pairings) successfully merged out of 26886 (in 6271 pairings) input.
# 11831 paired-reads (in 668 unique pairings) successfully merged out of 17623 (in 4616 pairings) input.
# 16777 paired-reads (in 799 unique pairings) successfully merged out of 20295 (in 3112 pairings) input.
# 16137 paired-reads (in 778 unique pairings) successfully merged out of 22295 (in 4922 pairings) input.
# 13522 paired-reads (in 626 unique pairings) successfully merged out of 19273 (in 4209 pairings) input.
# 13962 paired-reads (in 684 unique pairings) successfully merged out of 19192 (in 4288 pairings) input.
# 1469 paired-reads (in 68 unique pairings) successfully merged out of 1764 (in 230 pairings) input.
# 26616 paired-reads (in 1138 unique pairings) successfully merged out of 37992 (in 8968 pairings) input.
# 12653 paired-reads (in 645 unique pairings) successfully merged out of 19107 (in 5050 pairings) input.
# 12718 paired-reads (in 658 unique pairings) successfully merged out of 19342 (in 4970 pairings) input.
# 13024 paired-reads (in 639 unique pairings) successfully merged out of 18682 (in 4567 pairings) input.
# 14245 paired-reads (in 567 unique pairings) successfully merged out of 19244 (in 4031 pairings) input.
# 16647 paired-reads (in 733 unique pairings) successfully merged out of 21973 (in 4474 pairings) input.
# 14374 paired-reads (in 605 unique pairings) successfully merged out of 20334 (in 4588 pairings) input.
# 11800 paired-reads (in 528 unique pairings) successfully merged out of 15506 (in 3101 pairings) input.
# 14984 paired-reads (in 785 unique pairings) successfully merged out of 21545 (in 5071 pairings) input.
# 18446 paired-reads (in 732 unique pairings) successfully merged out of 24590 (in 5019 pairings) input.
# 15460 paired-reads (in 686 unique pairings) successfully merged out of 20952 (in 4440 pairings) input.
# 13095 paired-reads (in 591 unique pairings) successfully merged out of 17965 (in 3574 pairings) input.
# 13181 paired-reads (in 485 unique pairings) successfully merged out of 15641 (in 2049 pairings) input.
# 15789 paired-reads (in 682 unique pairings) successfully merged out of 21207 (in 4417 pairings) input.
# 17886 paired-reads (in 812 unique pairings) successfully merged out of 22716 (in 3975 pairings) input.
# 16552 paired-reads (in 881 unique pairings) successfully merged out of 21921 (in 4556 pairings) input.
# 12114 paired-reads (in 570 unique pairings) successfully merged out of 16428 (in 3504 pairings) input.
# 12649 paired-reads (in 545 unique pairings) successfully merged out of 16491 (in 3145 pairings) input.
# 15608 paired-reads (in 694 unique pairings) successfully merged out of 20674 (in 3942 pairings) input.
# 10547 paired-reads (in 634 unique pairings) successfully merged out of 16005 (in 4301 pairings) input.
# 14160 paired-reads (in 728 unique pairings) successfully merged out of 20826 (in 5310 pairings) input.
# 14123 paired-reads (in 713 unique pairings) successfully merged out of 19506 (in 4553 pairings) input.
# 16928 paired-reads (in 740 unique pairings) successfully merged out of 22699 (in 4733 pairings) input.
# 17568 paired-reads (in 697 unique pairings) successfully merged out of 23103 (in 4344 pairings) input.
# 12850 paired-reads (in 574 unique pairings) successfully merged out of 17364 (in 3585 pairings) input.
# 10608 paired-reads (in 480 unique pairings) successfully merged out of 14599 (in 2983 pairings) input.
# 13006 paired-reads (in 631 unique pairings) successfully merged out of 18628 (in 4472 pairings) input.
# 11859 paired-reads (in 606 unique pairings) successfully merged out of 16906 (in 3982 pairings) input.
# 12598 paired-reads (in 599 unique pairings) successfully merged out of 16849 (in 3528 pairings) input.
# 11646 paired-reads (in 505 unique pairings) successfully merged out of 15399 (in 2967 pairings) input.
# 10732 paired-reads (in 544 unique pairings) successfully merged out of 15239 (in 3604 pairings) input.
# 7328 paired-reads (in 315 unique pairings) successfully merged out of 9577 (in 1829 pairings) input.
# 12051 paired-reads (in 593 unique pairings) successfully merged out of 17264 (in 4221 pairings) input.
# 14805 paired-reads (in 695 unique pairings) successfully merged out of 20217 (in 4183 pairings) input.
# 13139 paired-reads (in 671 unique pairings) successfully merged out of 18941 (in 4470 pairings) input.
# 23302 paired-reads (in 1127 unique pairings) successfully merged out of 34312 (in 8408 pairings) input.
# 11063 paired-reads (in 570 unique pairings) successfully merged out of 16471 (in 4206 pairings) input.
# 20507 paired-reads (in 983 unique pairings) successfully merged out of 30748 (in 7969 pairings) input.
# 24780 paired-reads (in 1228 unique pairings) successfully merged out of 35373 (in 8674 pairings) input.
# 15001 paired-reads (in 511 unique pairings) successfully merged out of 18491 (in 2866 pairings) input.
# 13943 paired-reads (in 732 unique pairings) successfully merged out of 19464 (in 4675 pairings) input.
# 13575 paired-reads (in 687 unique pairings) successfully merged out of 17826 (in 3704 pairings) input.
# 14674 paired-reads (in 709 unique pairings) successfully merged out of 20088 (in 4467 pairings) input.
# 20925 paired-reads (in 967 unique pairings) successfully merged out of 30957 (in 7378 pairings) input.
# 25441 paired-reads (in 1084 unique pairings) successfully merged out of 35877 (in 7723 pairings) input.
# 11701 paired-reads (in 643 unique pairings) successfully merged out of 17810 (in 4750 pairings) input.
# 27083 paired-reads (in 1228 unique pairings) successfully merged out of 38802 (in 9053 pairings) input.
# 19670 paired-reads (in 932 unique pairings) successfully merged out of 29265 (in 7206 pairings) input.
# 16862 paired-reads (in 669 unique pairings) successfully merged out of 20710 (in 3181 pairings) input.
# 14714 paired-reads (in 689 unique pairings) successfully merged out of 20001 (in 4394 pairings) input.
# 13418 paired-reads (in 659 unique pairings) successfully merged out of 17878 (in 3701 pairings) input.
# 12861 paired-reads (in 673 unique pairings) successfully merged out of 17489 (in 3881 pairings) input.
# 25519 paired-reads (in 1112 unique pairings) successfully merged out of 35523 (in 7577 pairings) input.
# 23738 paired-reads (in 1039 unique pairings) successfully merged out of 33224 (in 7015 pairings) input.
# 22518 paired-reads (in 1133 unique pairings) successfully merged out of 33233 (in 8502 pairings) input.
# 14322 paired-reads (in 716 unique pairings) successfully merged out of 19867 (in 4462 pairings) input.
# 24874 paired-reads (in 1121 unique pairings) successfully merged out of 35020 (in 8075 pairings) input.
# 26713 paired-reads (in 1071 unique pairings) successfully merged out of 35452 (in 7133 pairings) input.
# 24504 paired-reads (in 1095 unique pairings) successfully merged out of 34502 (in 7923 pairings) input.
# 24352 paired-reads (in 1066 unique pairings) successfully merged out of 33111 (in 7154 pairings) input.

# %%
# Construct sequence table
seqtab <- makeSequenceTable(mergers)

# Check visually reads distribution by their merged length
reads.per.seqlen <- tapply(colSums(seqtab), factor(nchar(getSequences(seqtab))), sum)

df <- data.frame(length=as.numeric(names(reads.per.seqlen)), count=reads.per.seqlen)

readsDisr <- ggplot(data=df, aes(x=length, y=count)) + geom_col() + theme_bw()

# Save the plot 
ggsave("output/2_dada2/diagnostic_plots/leng_reads_distr.pdf", plot = readsDisr)

# Trim reads outside of reads distribution borders 
seqtab2 <- seqtab[,nchar(colnames(seqtab)) %in% seq(400, 430)]
# Out:
# Saving 6.67 x 6.67 in image

# %%
# Remove chimeras (will be majority of variants)
seqtab.nochim <- removeBimeraDenovo(seqtab2, method="consensus", multithread=TRUE, verbose=TRUE)

# Save ASV as R object and csv table 
save(seqtab.nochim, file = "output/2_dada2/objects/seqtab_nochim.RData")

write.csv(seqtab.nochim, file = "output/2_dada2/seqtab_nochim.csv")
# Out:
# Identified 33182 bimeras out of 48198 input sequences.

# %%
# Check how many sequenses get through 
getN <- function(x) sum(getUniques(x))

track <- cbind(out, sapply(dadaFs, getN), sapply(dadaRs, getN), 
               sapply(mergers, getN), rowSums(seqtab.nochim))
# If processing a single sample, remove the sapply calls: e.g. 
# replace sapply(dadaFs, getN) with getN(dadaFs)

colnames(track) <- c("input", "filtered", "denoisedF", "denoisedR", "merged", "nonchim")

rownames(track) <- sample.names

write.csv(track, file = "output/2_dada2/diagnostic_plots/track.csv")

# %%
# Taxonomy assignment  
#  Assign taxonomy using classical method 
taxa <- assignTaxonomy(seqtab.nochim, "resourses/silva_nr_v138_train_set.fa.gz",
                       multithread=TRUE)

# Save taxonomy table as csv and R object
write.csv(x = taxa, "output/2_dada2/taxa.csv")

save(taxa, file ="output/2_dada2/objects/taxa.RData")

# Assign taxonomy to species level using exact match 
# taxa.species <- addSpecies(taxa, "resourses/silva_species_assignment_v138.fa.gz")

# %%
# Read in metadata for samples 
metadata_final <- read.csv("output/1_shedding_analysis/metadata_f.csv")

rownames(metadata_final) <- metadata_final$NewId

# %%
rownames(seqtab.nochim) <- gsub("\\.gz", "", rownames(seqtab.nochim))

# %%
# Combine taxonomic table, ASV count table and metadata into a pholoseq object. 
ps <- phyloseq(otu_table(seqtab.nochim, taxa_are_rows=FALSE), 
               sample_data(metadata_final), 
               tax_table(taxa))

# Save phyloseq object 
save(ps, file = "output/2_dada2/phyloseq0.RData")
saveRDS(ps, "output/2_dada2/phyloseq0.rds")
