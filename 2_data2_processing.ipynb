# %%
###################################
# ASV picking using DADA2 pipeline
###################################

# According to http://benjjneb.github.io/dada2/tutorial.html

# %%
# Prepare folder for dada2 output: 
dir.create("output/2_dada2")

dir.create("output/2_dada2/diagnostic_plots")

dir.create("output/2_dada2/objects")

# %%
# Load libraries 
source("scr/functions/general/load_abs_install_pkg.R")

load_abs_install_pkg(c("dada2", "phyloseq", "tidyverse"))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE

# %%
# Make a list of fastq files in the directory 
path = "data/Dada2_input/"

files <- list.files(path)

files <- files[grep(".fastq", files)]

# %%
# Separate forward and revers reads into different variables 
fnFs <- sort(list.files(path, pattern="R1.fastq", full.names = TRUE))

fnRs <- sort(list.files(path, pattern="R2.fastq", full.names = TRUE))

# %%
# Make a variable containing only files names 
sample.names <- unique(gsub("_R1.fastq|_R2.fastq", "", files))

# %%
# Check reads quality by graphing 
#   Plots are saved in "output/dada2/diagnostic_plots"
forwReads <- plotQualityProfile(fnFs[1:4])

revReads <-plotQualityProfile(fnRs[1:4])

ggsave("output/2_dada2/diagnostic_plots/forward_reads_qualty.pdf", plot = forwReads )

ggsave("output/2_dada2/diagnostic_plots/revers_reads_qualty.pdf", plot = revReads )
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Saving 6.67 x 6.67 in image
# Saving 6.67 x 6.67 in image

# %%
# Prepare directory and names for filtered files 
filtFs <- file.path(path, "filtered", paste0(sample.names, "_F_filt.fastq.gz"))

filtRs <- file.path(path, "filtered", paste0(sample.names, "_R_filt.fastq.gz"))

names(filtFs) <- sample.names

names(filtRs) <- sample.names

# %%
out <- filterAndTrim(fnFs, filtFs, fnRs, filtRs, 
                     truncLen=c(280, 240), # Truncet bad reads at the end of the reads 
                     # however keep in mind that reads should overlap at least 20bp
                     # in our case amplicon is 444 nucleotide long, so total length should be 464 at least. 
                     trimLeft = c(17, 21), # Trim primers from the begining of sequence                       
                     maxN=0, 
                     maxEE=c(1,1), 
                     truncQ=2, 
                     rm.phix=TRUE,
                     compress=TRUE, 
                     multithread=TRUE) #only for Linux

# %%
# Learn errors in sequences for forward and reverse reads 
errF <- learnErrors(filtFs, multithread=TRUE, nbases = 2e8)

errR <- learnErrors(filtRs, multithread=TRUE, nbases = 2e8)

save(list = c("errF", "errR"), file="output/2_dada2/objects/error_rate_FR.RData")
# Out:
# 204404389 total bases in 777203 reads from 26 samples will be used for learning the error rates.
# 200785113 total bases in 916827 reads from 30 samples will be used for learning the error rates.

# %%
errFplot <- plotErrors(errF, nominalQ=TRUE)

errRplot <- plotErrors(errR, nominalQ=TRUE)


# Save plots in output/dada2/diagnostic_plots/
ggsave("output/2_dada2/diagnostic_plots/error_rate_F.pdf", plot = errFplot)

ggsave("output/2_dada2/diagnostic_plots/error_rate_R.pdf", plot = errRplot)
# Out:
# Saving 6.67 x 6.67 in image
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Saving 6.67 x 6.67 in image
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”

# %%
# Dereplication - combine identical sequences into unique with corresponding number 
#                    of reads 
derepFs <- derepFastq(filtFs, verbose=FALSE)

derepRs <- derepFastq(filtRs, verbose=FALSE)

# Name the derep-class objects by the sample names
names(derepFs) <- sample.names

names(derepRs) <- sample.names

# Save dereplicated objects 
save(derepFs, file="output/2_dada2/objects/derepFs.RData")

save(derepRs, file="output/2_dada2/objects/derepRs.RData")

# %%
# Samples inference 
#      *addiotion of (..., pool=TRUE) argument could increase sensetivity for rear variates 
dadaFs <- dada(derepFs, err=errF, multithread=TRUE)

dadaRs <- dada(derepRs, err=errR, multithread=TRUE)

# Back up generated objects 
save(dadaFs, file="output/2_dada2/objects/dadaFs.RData")

save(dadaRs, file="output/2_dada2/objects/dadaRs.RData")
# Out:
# Sample 1 - 25711 reads in 8609 unique sequences.
# Sample 2 - 20402 reads in 10848 unique sequences.
# Sample 3 - 21412 reads in 9209 unique sequences.
# Sample 4 - 18693 reads in 8771 unique sequences.
# Sample 5 - 42664 reads in 20084 unique sequences.
# Sample 6 - 41697 reads in 19934 unique sequences.
# Sample 7 - 18062 reads in 10909 unique sequences.
# Sample 8 - 38713 reads in 19433 unique sequences.
# Sample 9 - 39967 reads in 16433 unique sequences.
# Sample 10 - 47249 reads in 23758 unique sequences.
# Sample 11 - 42551 reads in 20342 unique sequences.
# Sample 12 - 24232 reads in 11046 unique sequences.
# Sample 13 - 22848 reads in 10319 unique sequences.
# Sample 14 - 22982 reads in 10265 unique sequences.
# Sample 15 - 51530 reads in 24836 unique sequences.
# Sample 16 - 16 reads in 13 unique sequences.
# Sample 17 - 40261 reads in 18651 unique sequences.
# Sample 18 - 19352 reads in 10054 unique sequences.
# Sample 19 - 45853 reads in 22904 unique sequences.
# Sample 20 - 40695 reads in 19659 unique sequences.
# Sample 21 - 44818 reads in 22145 unique sequences.
# Sample 22 - 40718 reads in 19981 unique sequences.
# Sample 23 - 6 reads in 5 unique sequences.
# Sample 24 - 22918 reads in 11369 unique sequences.
# Sample 25 - 20676 reads in 9892 unique sequences.
# Sample 26 - 23177 reads in 10612 unique sequences.
# Sample 27 - 39587 reads in 13757 unique sequences.
# Sample 28 - 40720 reads in 19450 unique sequences.
# Sample 29 - 21180 reads in 12140 unique sequences.
# Sample 30 - 38137 reads in 21402 unique sequences.
# Sample 31 - 34482 reads in 18740 unique sequences.
# Sample 32 - 40928 reads in 19150 unique sequences.
# Sample 33 - 42095 reads in 20711 unique sequences.
# Sample 34 - 38174 reads in 19727 unique sequences.
# Sample 35 - 39066 reads in 17540 unique sequences.
# Sample 36 - 25862 reads in 13363 unique sequences.
# Sample 37 - 20398 reads in 10910 unique sequences.
# Sample 38 - 20587 reads in 11559 unique sequences.
# Sample 39 - 21419 reads in 12544 unique sequences.
# Sample 40 - 21806 reads in 13350 unique sequences.
# Sample 41 - 18213 reads in 10300 unique sequences.
# Sample 42 - 23917 reads in 11753 unique sequences.
# Sample 43 - 29447 reads in 15389 unique sequences.
# Sample 44 - 23241 reads in 13460 unique sequences.
# Sample 45 - 24795 reads in 13885 unique sequences.
# Sample 46 - 20133 reads in 11742 unique sequences.
# Sample 47 - 25652 reads in 13717 unique sequences.
# Sample 48 - 15295 reads in 9081 unique sequences.
# Sample 49 - 28151 reads in 11162 unique sequences.
# Sample 50 - 24003 reads in 10860 unique sequences.
# Sample 51 - 23634 reads in 9672 unique sequences.
# Sample 52 - 22224 reads in 11215 unique sequences.
# Sample 53 - 27605 reads in 12136 unique sequences.
# Sample 54 - 22441 reads in 9817 unique sequences.
# Sample 55 - 31418 reads in 17041 unique sequences.
# Sample 56 - 78162 reads in 32228 unique sequences.
# Sample 57 - 23810 reads in 13099 unique sequences.
# Sample 58 - 43776 reads in 19573 unique sequences.
# Sample 59 - 39610 reads in 19444 unique sequences.
# Sample 60 - 21724 reads in 8969 unique sequences.
# Sample 61 - 25236 reads in 12716 unique sequences.
# Sample 62 - 23302 reads in 11435 unique sequences.
# Sample 63 - 22932 reads in 10879 unique sequences.
# Sample 64 - 37572 reads in 20492 unique sequences.
# Sample 65 - 41987 reads in 20895 unique sequences.
# Sample 66 - 25035 reads in 14507 unique sequences.
# Sample 67 - 38663 reads in 19633 unique sequences.
# Sample 68 - 37800 reads in 19613 unique sequences.
# Sample 69 - 16188 reads in 7845 unique sequences.
# Sample 70 - 21522 reads in 10915 unique sequences.
# Sample 71 - 23239 reads in 7526 unique sequences.
# Sample 72 - 26292 reads in 9123 unique sequences.
# Sample 73 - 37909 reads in 19225 unique sequences.
# Sample 74 - 40226 reads in 17435 unique sequences.
# Sample 75 - 22806 reads in 11264 unique sequences.
# Sample 76 - 43415 reads in 21208 unique sequences.
# Sample 77 - 41346 reads in 18943 unique sequences.
# Sample 78 - 17200 reads in 7283 unique sequences.
# Sample 79 - 22427 reads in 10970 unique sequences.
# Sample 80 - 22271 reads in 9858 unique sequences.
# Sample 81 - 37846 reads in 19143 unique sequences.
# Sample 82 - 43086 reads in 19629 unique sequences.
# Sample 83 - 52 reads in 48 unique sequences.
# Sample 84 - 21431 reads in 12349 unique sequences.
# Sample 85 - 37852 reads in 20929 unique sequences.
# Sample 86 - 38268 reads in 19866 unique sequences.
# Sample 87 - 40183 reads in 18800 unique sequences.
# Sample 88 - 38631 reads in 19828 unique sequences.
# Sample 89 - 44924 reads in 21827 unique sequences.
# Sample 90 - 36046 reads in 18359 unique sequences.
# Sample 91 - 19883 reads in 7988 unique sequences.
# Sample 92 - 20451 reads in 10674 unique sequences.
# Sample 93 - 29434 reads in 14853 unique sequences.
# Sample 94 - 21617 reads in 10474 unique sequences.
# Sample 95 - 20020 reads in 9504 unique sequences.
# Sample 96 - 39959 reads in 18496 unique sequences.
# Sample 97 - 25035 reads in 12737 unique sequences.
# Sample 98 - 23820 reads in 12941 unique sequences.
# Sample 99 - 26760 reads in 13998 unique sequences.
# Sample 100 - 25050 reads in 13846 unique sequences.
# Sample 101 - 25365 reads in 12631 unique sequences.
# Sample 102 - 28964 reads in 13811 unique sequences.
# Sample 103 - 30636 reads in 15331 unique sequences.
# Sample 104 - 27451 reads in 13218 unique sequences.
# Sample 105 - 28275 reads in 14375 unique sequences.
# Sample 106 - 27166 reads in 13229 unique sequences.
# Sample 107 - 25043 reads in 12341 unique sequences.
# Sample 108 - 21342 reads in 10586 unique sequences.
# Sample 109 - 25957 reads in 12500 unique sequences.
# Sample 110 - 25133 reads in 10290 unique sequences.
# Sample 111 - 21104 reads in 11437 unique sequences.
# Sample 112 - 25628 reads in 12054 unique sequences.
# Sample 113 - 22242 reads in 11954 unique sequences.
# Sample 114 - 39169 reads in 20091 unique sequences.
# Sample 115 - 43939 reads in 22599 unique sequences.
# Sample 116 - 17789 reads in 10068 unique sequences.
# Sample 117 - 41772 reads in 21454 unique sequences.
# Sample 118 - 46747 reads in 23592 unique sequences.
# Sample 119 - 40568 reads in 18830 unique sequences.
# Sample 120 - 41590 reads in 21117 unique sequences.
# Sample 121 - 38575 reads in 18465 unique sequences.
# Sample 122 - 22705 reads in 9625 unique sequences.
# Sample 123 - 24261 reads in 12639 unique sequences.
# Sample 124 - 24656 reads in 11818 unique sequences.
# Sample 125 - 13295 reads in 7402 unique sequences.
# Sample 126 - 28 reads in 28 unique sequences.
# Sample 127 - 35951 reads in 20090 unique sequences.
# Sample 128 - 23356 reads in 13576 unique sequences.
# Sample 129 - 44972 reads in 22397 unique sequences.
# Sample 130 - 43551 reads in 22416 unique sequences.
# Sample 131 - 1429 reads in 1067 unique sequences.
# Sample 132 - 19585 reads in 9386 unique sequences.
# Sample 133 - 22985 reads in 11700 unique sequences.
# Sample 134 - 28844 reads in 13620 unique sequences.
# Sample 135 - 21571 reads in 10407 unique sequences.
# Sample 136 - 23291 reads in 11424 unique sequences.
# Sample 137 - 20133 reads in 10249 unique sequences.
# Sample 138 - 33587 reads in 18581 unique sequences.
# Sample 139 - 25091 reads in 13018 unique sequences.
# Sample 140 - 45644 reads in 22557 unique sequences.
# Sample 141 - 45125 reads in 21162 unique sequences.
# Sample 142 - 25720 reads in 13625 unique sequences.
# Sample 143 - 28813 reads in 12100 unique sequences.
# Sample 144 - 25667 reads in 12928 unique sequences.
# Sample 145 - 23747 reads in 11590 unique sequences.
# Sample 146 - 24946 reads in 12622 unique sequences.
# Sample 147 - 26880 reads in 12600 unique sequences.
# Sample 148 - 28661 reads in 14246 unique sequences.
# Sample 149 - 30697 reads in 14797 unique sequences.
# Sample 150 - 22796 reads in 11815 unique sequences.
# Sample 151 - 26875 reads in 12512 unique sequences.
# Sample 152 - 24514 reads in 9704 unique sequences.
# Sample 153 - 22220 reads in 11113 unique sequences.
# Sample 154 - 26932 reads in 12332 unique sequences.
# Sample 155 - 22665 reads in 10219 unique sequences.
# Sample 156 - 20820 reads in 10137 unique sequences.
# Sample 157 - 40733 reads in 20375 unique sequences.
# Sample 158 - 39123 reads in 21292 unique sequences.
# Sample 159 - 37073 reads in 18067 unique sequences.
# Sample 160 - 38820 reads in 21839 unique sequences.
# Sample 161 - 22199 reads in 12001 unique sequences.
# Sample 162 - 40512 reads in 20768 unique sequences.
# Sample 163 - 25312 reads in 12282 unique sequences.
# Sample 164 - 26974 reads in 13640 unique sequences.
# Sample 165 - 21330 reads in 11607 unique sequences.
# Sample 166 - 26200 reads in 13784 unique sequences.
# Sample 167 - 26004 reads in 13714 unique sequences.
# Sample 168 - 36073 reads in 18028 unique sequences.
# Sample 169 - 24696 reads in 13383 unique sequences.
# Sample 170 - 28014 reads in 14520 unique sequences.
# Sample 171 - 26500 reads in 13613 unique sequences.
# Sample 172 - 20522 reads in 11132 unique sequences.
# Sample 173 - 31436 reads in 15405 unique sequences.
# Sample 174 - 20175 reads in 8966 unique sequences.
# Sample 175 - 21050 reads in 11160 unique sequences.
# Sample 176 - 21652 reads in 10074 unique sequences.
# Sample 177 - 20702 reads in 10531 unique sequences.
# Sample 178 - 44995 reads in 23675 unique sequences.
# Sample 179 - 29867 reads in 16337 unique sequences.
# Sample 180 - 21440 reads in 12733 unique sequences.
# Sample 181 - 35823 reads in 19874 unique sequences.
# Sample 182 - 35860 reads in 17826 unique sequences.
# Sample 183 - 25364 reads in 10821 unique sequences.
# Sample 184 - 21733 reads in 10608 unique sequences.
# Sample 185 - 23500 reads in 10721 unique sequences.
# Sample 186 - 3425 reads in 2326 unique sequences.
# Sample 187 - 40844 reads in 20069 unique sequences.
# Sample 188 - 33084 reads in 16073 unique sequences.
# Sample 189 - 25783 reads in 13385 unique sequences.
# Sample 190 - 42020 reads in 21092 unique sequences.
# Sample 191 - 34832 reads in 16678 unique sequences.
# Sample 192 - 42711 reads in 20008 unique sequences.
# Sample 193 - 7968 reads in 4823 unique sequences.
# Sample 194 - 38273 reads in 19437 unique sequences.
# Sample 195 - 32274 reads in 16698 unique sequences.
# Sample 196 - 21766 reads in 12425 unique sequences.
# Sample 197 - 22431 reads in 8964 unique sequences.
# Sample 198 - 26905 reads in 13959 unique sequences.
# Sample 199 - 23224 reads in 13000 unique sequences.
# Sample 200 - 23252 reads in 12081 unique sequences.
# Sample 201 - 2169 reads in 971 unique sequences.
# Sample 202 - 44099 reads in 22535 unique sequences.
# Sample 203 - 23617 reads in 13707 unique sequences.
# Sample 204 - 23974 reads in 14092 unique sequences.
# Sample 205 - 22914 reads in 12886 unique sequences.
# Sample 206 - 22972 reads in 11876 unique sequences.
# Sample 207 - 26034 reads in 12634 unique sequences.
# Sample 208 - 24446 reads in 13480 unique sequences.
# Sample 209 - 18542 reads in 9317 unique sequences.
# Sample 210 - 26192 reads in 14414 unique sequences.
# Sample 211 - 29155 reads in 13950 unique sequences.
# Sample 212 - 24943 reads in 12468 unique sequences.
# Sample 213 - 22012 reads in 11504 unique sequences.
# Sample 214 - 17254 reads in 6813 unique sequences.
# Sample 215 - 25170 reads in 12185 unique sequences.
# Sample 216 - 25582 reads in 11231 unique sequences.
# Sample 217 - 25317 reads in 12396 unique sequences.
# Sample 218 - 19720 reads in 10484 unique sequences.
# Sample 219 - 19699 reads in 9457 unique sequences.
# Sample 220 - 24611 reads in 12015 unique sequences.
# Sample 221 - 19838 reads in 11613 unique sequences.
# Sample 222 - 25735 reads in 14196 unique sequences.
# Sample 223 - 23071 reads in 12249 unique sequences.
# Sample 224 - 27200 reads in 13758 unique sequences.
# Sample 225 - 27459 reads in 12955 unique sequences.
# Sample 226 - 20995 reads in 10649 unique sequences.
# Sample 227 - 18963 reads in 10608 unique sequences.
# Sample 228 - 22824 reads in 12322 unique sequences.
# Sample 229 - 20991 reads in 11654 unique sequences.
# Sample 230 - 20530 reads in 10403 unique sequences.
# Sample 231 - 18654 reads in 9617 unique sequences.
# Sample 232 - 18712 reads in 10302 unique sequences.
# Sample 233 - 11194 reads in 5687 unique sequences.
# Sample 234 - 20847 reads in 11113 unique sequences.
# Sample 235 - 23245 reads in 10657 unique sequences.
# Sample 236 - 22007 reads in 11170 unique sequences.
# Sample 237 - 39499 reads in 21578 unique sequences.
# Sample 238 - 20221 reads in 11762 unique sequences.
# Sample 239 - 37121 reads in 20827 unique sequences.
# Sample 240 - 41703 reads in 21157 unique sequences.
# Sample 241 - 20805 reads in 8694 unique sequences.
# Sample 242 - 22857 reads in 11457 unique sequences.
# Sample 243 - 20409 reads in 9452 unique sequences.
# Sample 244 - 23781 reads in 11843 unique sequences.
# Sample 245 - 36710 reads in 20298 unique sequences.
# Sample 246 - 42462 reads in 22023 unique sequences.
# Sample 247 - 21982 reads in 12572 unique sequences.
# Sample 248 - 45666 reads in 24420 unique sequences.
# Sample 249 - 35612 reads in 20144 unique sequences.
# Sample 250 - 23251 reads in 9720 unique sequences.
# Sample 251 - 23483 reads in 11567 unique sequences.
# Sample 252 - 21199 reads in 10188 unique sequences.
# Sample 253 - 20442 reads in 10235 unique sequences.
# Sample 254 - 40981 reads in 20911 unique sequences.
# Sample 255 - 38711 reads in 18748 unique sequences.
# Sample 256 - 39210 reads in 21385 unique sequences.
# Sample 257 - 24130 reads in 13127 unique sequences.
# Sample 258 - 39305 reads in 18870 unique sequences.
# Sample 259 - 40914 reads in 20442 unique sequences.
# Sample 260 - 41179 reads in 18899 unique sequences.
# Sample 261 - 40402 reads in 20183 unique sequences.
# Sample 262 - 39267 reads in 18851 unique sequences.
# Sample 1 - 25711 reads in 6515 unique sequences.
# Sample 2 - 20402 reads in 7909 unique sequences.
# Sample 3 - 21412 reads in 7055 unique sequences.
# Sample 4 - 18693 reads in 6502 unique sequences.
# Sample 5 - 42664 reads in 16975 unique sequences.
# Sample 6 - 41697 reads in 16498 unique sequences.
# Sample 7 - 18062 reads in 8576 unique sequences.
# Sample 8 - 38713 reads in 14520 unique sequences.
# Sample 9 - 39967 reads in 15032 unique sequences.
# Sample 10 - 47249 reads in 19033 unique sequences.
# Sample 11 - 42551 reads in 17660 unique sequences.
# Sample 12 - 24232 reads in 8834 unique sequences.
# Sample 13 - 22848 reads in 7670 unique sequences.
# Sample 14 - 22982 reads in 7608 unique sequences.
# Sample 15 - 51530 reads in 19273 unique sequences.
# Sample 16 - 16 reads in 14 unique sequences.
# Sample 17 - 40261 reads in 15667 unique sequences.
# Sample 18 - 19352 reads in 7636 unique sequences.
# Sample 19 - 45853 reads in 19376 unique sequences.
# Sample 20 - 40695 reads in 15411 unique sequences.
# Sample 21 - 44818 reads in 17846 unique sequences.
# Sample 22 - 40718 reads in 16688 unique sequences.
# Sample 23 - 6 reads in 5 unique sequences.
# Sample 24 - 22918 reads in 9077 unique sequences.
# Sample 25 - 20676 reads in 7717 unique sequences.
# Sample 26 - 23177 reads in 8496 unique sequences.
# Sample 27 - 39587 reads in 12176 unique sequences.
# Sample 28 - 40720 reads in 15371 unique sequences.
# Sample 29 - 21180 reads in 9073 unique sequences.
# Sample 30 - 38137 reads in 17823 unique sequences.
# Sample 31 - 34482 reads in 14549 unique sequences.
# Sample 32 - 40928 reads in 15454 unique sequences.
# Sample 33 - 42095 reads in 16944 unique sequences.
# Sample 34 - 38174 reads in 16000 unique sequences.
# Sample 35 - 39066 reads in 14429 unique sequences.
# Sample 36 - 25862 reads in 10584 unique sequences.
# Sample 37 - 20398 reads in 8453 unique sequences.
# Sample 38 - 20587 reads in 8697 unique sequences.
# Sample 39 - 21419 reads in 9813 unique sequences.
# Sample 40 - 21806 reads in 10874 unique sequences.
# Sample 41 - 18213 reads in 8329 unique sequences.
# Sample 42 - 23917 reads in 9432 unique sequences.
# Sample 43 - 29447 reads in 11909 unique sequences.
# Sample 44 - 23241 reads in 10588 unique sequences.
# Sample 45 - 24795 reads in 10725 unique sequences.
# Sample 46 - 20133 reads in 9151 unique sequences.
# Sample 47 - 25652 reads in 10586 unique sequences.
# Sample 48 - 15295 reads in 6780 unique sequences.
# Sample 49 - 28151 reads in 8569 unique sequences.
# Sample 50 - 24003 reads in 8744 unique sequences.
# Sample 51 - 23634 reads in 6876 unique sequences.
# Sample 52 - 22224 reads in 8072 unique sequences.
# Sample 53 - 27605 reads in 9373 unique sequences.
# Sample 54 - 22441 reads in 7450 unique sequences.
# Sample 55 - 31418 reads in 13442 unique sequences.
# Sample 56 - 78162 reads in 24573 unique sequences.
# Sample 57 - 23810 reads in 10515 unique sequences.
# Sample 58 - 43776 reads in 16695 unique sequences.
# Sample 59 - 39610 reads in 16293 unique sequences.
# Sample 60 - 21724 reads in 6202 unique sequences.
# Sample 61 - 25236 reads in 9379 unique sequences.
# Sample 62 - 23302 reads in 8603 unique sequences.
# Sample 63 - 22932 reads in 8036 unique sequences.
# Sample 64 - 37572 reads in 15615 unique sequences.
# Sample 65 - 41987 reads in 18079 unique sequences.
# Sample 66 - 25035 reads in 11297 unique sequences.
# Sample 67 - 38663 reads in 16164 unique sequences.
# Sample 68 - 37800 reads in 15853 unique sequences.
# Sample 69 - 16188 reads in 5639 unique sequences.
# Sample 70 - 21522 reads in 8207 unique sequences.
# Sample 71 - 23239 reads in 5780 unique sequences.
# Sample 72 - 26292 reads in 7666 unique sequences.
# Sample 73 - 37909 reads in 15370 unique sequences.
# Sample 74 - 40226 reads in 14032 unique sequences.
# Sample 75 - 22806 reads in 8699 unique sequences.
# Sample 76 - 43415 reads in 17291 unique sequences.
# Sample 77 - 41346 reads in 15241 unique sequences.
# Sample 78 - 17200 reads in 5804 unique sequences.
# Sample 79 - 22427 reads in 8337 unique sequences.
# Sample 80 - 22271 reads in 7620 unique sequences.
# Sample 81 - 37846 reads in 14934 unique sequences.
# Sample 82 - 43086 reads in 16266 unique sequences.
# Sample 83 - 52 reads in 46 unique sequences.
# Sample 84 - 21431 reads in 9390 unique sequences.
# Sample 85 - 37852 reads in 16287 unique sequences.
# Sample 86 - 38268 reads in 15705 unique sequences.
# Sample 87 - 40183 reads in 15883 unique sequences.
# Sample 88 - 38631 reads in 17166 unique sequences.
# Sample 89 - 44924 reads in 18274 unique sequences.
# Sample 90 - 36046 reads in 14631 unique sequences.
# Sample 91 - 19883 reads in 5846 unique sequences.
# Sample 92 - 20451 reads in 7757 unique sequences.
# Sample 93 - 29434 reads in 11394 unique sequences.
# Sample 94 - 21617 reads in 7922 unique sequences.
# Sample 95 - 20020 reads in 6548 unique sequences.
# Sample 96 - 39959 reads in 15219 unique sequences.
# Sample 97 - 25035 reads in 9371 unique sequences.
# Sample 98 - 23820 reads in 10326 unique sequences.
# Sample 99 - 26760 reads in 11194 unique sequences.
# Sample 100 - 25050 reads in 10793 unique sequences.
# Sample 101 - 25365 reads in 10443 unique sequences.
# Sample 102 - 28964 reads in 11307 unique sequences.
# Sample 103 - 30636 reads in 12259 unique sequences.
# Sample 104 - 27451 reads in 10401 unique sequences.
# Sample 105 - 28275 reads in 11428 unique sequences.
# Sample 106 - 27166 reads in 10297 unique sequences.
# Sample 107 - 25043 reads in 10062 unique sequences.
# Sample 108 - 21342 reads in 8843 unique sequences.
# Sample 109 - 25957 reads in 9567 unique sequences.
# Sample 110 - 25133 reads in 7621 unique sequences.
# Sample 111 - 21104 reads in 8458 unique sequences.
# Sample 112 - 25628 reads in 9026 unique sequences.
# Sample 113 - 22242 reads in 8921 unique sequences.
# Sample 114 - 39169 reads in 16212 unique sequences.
# Sample 115 - 43939 reads in 16941 unique sequences.
# Sample 116 - 17789 reads in 7319 unique sequences.
# Sample 117 - 41772 reads in 17024 unique sequences.
# Sample 118 - 46747 reads in 18475 unique sequences.
# Sample 119 - 40568 reads in 15191 unique sequences.
# Sample 120 - 41590 reads in 16888 unique sequences.
# Sample 121 - 38575 reads in 14835 unique sequences.
# Sample 122 - 22705 reads in 7549 unique sequences.
# Sample 123 - 24261 reads in 9787 unique sequences.
# Sample 124 - 24656 reads in 9812 unique sequences.
# Sample 125 - 13295 reads in 6146 unique sequences.
# Sample 126 - 28 reads in 27 unique sequences.
# Sample 127 - 35951 reads in 16167 unique sequences.
# Sample 128 - 23356 reads in 10591 unique sequences.
# Sample 129 - 44972 reads in 17420 unique sequences.
# Sample 130 - 43551 reads in 17823 unique sequences.
# Sample 131 - 1429 reads in 926 unique sequences.
# Sample 132 - 19585 reads in 7000 unique sequences.
# Sample 133 - 22985 reads in 8804 unique sequences.
# Sample 134 - 28844 reads in 10725 unique sequences.
# Sample 135 - 21571 reads in 7984 unique sequences.
# Sample 136 - 23291 reads in 8495 unique sequences.
# Sample 137 - 20133 reads in 8317 unique sequences.
# Sample 138 - 33587 reads in 14858 unique sequences.
# Sample 139 - 25091 reads in 10057 unique sequences.
# Sample 140 - 45644 reads in 18822 unique sequences.
# Sample 141 - 45125 reads in 17883 unique sequences.
# Sample 142 - 25720 reads in 10613 unique sequences.
# Sample 143 - 28813 reads in 10600 unique sequences.
# Sample 144 - 25667 reads in 10326 unique sequences.
# Sample 145 - 23747 reads in 8979 unique sequences.
# Sample 146 - 24946 reads in 10003 unique sequences.
# Sample 147 - 26880 reads in 10121 unique sequences.
# Sample 148 - 28661 reads in 11377 unique sequences.
# Sample 149 - 30697 reads in 11324 unique sequences.
# Sample 150 - 22796 reads in 9964 unique sequences.
# Sample 151 - 26875 reads in 9473 unique sequences.
# Sample 152 - 24514 reads in 7430 unique sequences.
# Sample 153 - 22220 reads in 8589 unique sequences.
# Sample 154 - 26932 reads in 9560 unique sequences.
# Sample 155 - 22665 reads in 7987 unique sequences.
# Sample 156 - 20820 reads in 7816 unique sequences.
# Sample 157 - 40733 reads in 16388 unique sequences.
# Sample 158 - 39123 reads in 16043 unique sequences.
# Sample 159 - 37073 reads in 14403 unique sequences.
# Sample 160 - 38820 reads in 16755 unique sequences.
# Sample 161 - 22199 reads in 9074 unique sequences.
# Sample 162 - 40512 reads in 16499 unique sequences.
# Sample 163 - 25312 reads in 9867 unique sequences.
# Sample 164 - 26974 reads in 11167 unique sequences.
# Sample 165 - 21330 reads in 9649 unique sequences.
# Sample 166 - 26200 reads in 11408 unique sequences.
# Sample 167 - 26004 reads in 10517 unique sequences.
# Sample 168 - 36073 reads in 14991 unique sequences.
# Sample 169 - 24696 reads in 10672 unique sequences.
# Sample 170 - 28014 reads in 11613 unique sequences.
# Sample 171 - 26500 reads in 10899 unique sequences.
# Sample 172 - 20522 reads in 8992 unique sequences.
# Sample 173 - 31436 reads in 12350 unique sequences.
# Sample 174 - 20175 reads in 6539 unique sequences.
# Sample 175 - 21050 reads in 8321 unique sequences.
# Sample 176 - 21652 reads in 7817 unique sequences.
# Sample 177 - 20702 reads in 8165 unique sequences.
# Sample 178 - 44995 reads in 18653 unique sequences.
# Sample 179 - 29867 reads in 14616 unique sequences.
# Sample 180 - 21440 reads in 10337 unique sequences.
# Sample 181 - 35823 reads in 16285 unique sequences.
# Sample 182 - 35860 reads in 14814 unique sequences.
# Sample 183 - 25364 reads in 8303 unique sequences.
# Sample 184 - 21733 reads in 8120 unique sequences.
# Sample 185 - 23500 reads in 8444 unique sequences.
# Sample 186 - 3425 reads in 2228 unique sequences.
# Sample 187 - 40844 reads in 16754 unique sequences.
# Sample 188 - 33084 reads in 12561 unique sequences.
# Sample 189 - 25783 reads in 10313 unique sequences.
# Sample 190 - 42020 reads in 17239 unique sequences.
# Sample 191 - 34832 reads in 14224 unique sequences.
# Sample 192 - 42711 reads in 17084 unique sequences.
# Sample 193 - 7968 reads in 5297 unique sequences.
# Sample 194 - 38273 reads in 16806 unique sequences.
# Sample 195 - 32274 reads in 12896 unique sequences.
# Sample 196 - 21766 reads in 9331 unique sequences.
# Sample 197 - 22431 reads in 6105 unique sequences.
# Sample 198 - 26905 reads in 10612 unique sequences.
# Sample 199 - 23224 reads in 10433 unique sequences.
# Sample 200 - 23252 reads in 9230 unique sequences.
# Sample 201 - 2169 reads in 896 unique sequences.
# Sample 202 - 44099 reads in 18606 unique sequences.
# Sample 203 - 23617 reads in 10627 unique sequences.
# Sample 204 - 23974 reads in 10709 unique sequences.
# Sample 205 - 22914 reads in 10255 unique sequences.
# Sample 206 - 22972 reads in 9307 unique sequences.
# Sample 207 - 26034 reads in 10200 unique sequences.
# Sample 208 - 24446 reads in 10876 unique sequences.
# Sample 209 - 18542 reads in 7418 unique sequences.
# Sample 210 - 26192 reads in 11229 unique sequences.
# Sample 211 - 29155 reads in 11329 unique sequences.
# Sample 212 - 24943 reads in 10277 unique sequences.
# Sample 213 - 22012 reads in 9525 unique sequences.
# Sample 214 - 17254 reads in 5361 unique sequences.
# Sample 215 - 25170 reads in 10229 unique sequences.
# Sample 216 - 25582 reads in 8032 unique sequences.
# Sample 217 - 25317 reads in 8699 unique sequences.
# Sample 218 - 19720 reads in 8047 unique sequences.
# Sample 219 - 19699 reads in 7507 unique sequences.
# Sample 220 - 24611 reads in 10213 unique sequences.
# Sample 221 - 19838 reads in 9506 unique sequences.
# Sample 222 - 25735 reads in 10837 unique sequences.
# Sample 223 - 23071 reads in 9605 unique sequences.
# Sample 224 - 27200 reads in 11488 unique sequences.
# Sample 225 - 27459 reads in 10566 unique sequences.
# Sample 226 - 20995 reads in 9030 unique sequences.
# Sample 227 - 18963 reads in 8717 unique sequences.
# Sample 228 - 22824 reads in 9604 unique sequences.
# Sample 229 - 20991 reads in 9249 unique sequences.
# Sample 230 - 20530 reads in 8121 unique sequences.
# Sample 231 - 18654 reads in 7822 unique sequences.
# Sample 232 - 18712 reads in 7913 unique sequences.
# Sample 233 - 11194 reads in 4113 unique sequences.
# Sample 234 - 20847 reads in 8356 unique sequences.
# Sample 235 - 23245 reads in 8474 unique sequences.
# Sample 236 - 22007 reads in 8494 unique sequences.
# Sample 237 - 39499 reads in 17095 unique sequences.
# Sample 238 - 20221 reads in 9347 unique sequences.
# Sample 239 - 37121 reads in 16234 unique sequences.
# Sample 240 - 41703 reads in 17159 unique sequences.
# Sample 241 - 20805 reads in 6634 unique sequences.
# Sample 242 - 22857 reads in 8818 unique sequences.
# Sample 243 - 20409 reads in 7154 unique sequences.
# Sample 244 - 23781 reads in 9099 unique sequences.
# Sample 245 - 36710 reads in 15843 unique sequences.
# Sample 246 - 42462 reads in 18699 unique sequences.
# Sample 247 - 21982 reads in 9379 unique sequences.
# Sample 248 - 45666 reads in 19712 unique sequences.
# Sample 249 - 35612 reads in 16150 unique sequences.
# Sample 250 - 23251 reads in 6888 unique sequences.
# Sample 251 - 23483 reads in 8597 unique sequences.
# Sample 252 - 21199 reads in 8011 unique sequences.
# Sample 253 - 20442 reads in 7695 unique sequences.
# Sample 254 - 40981 reads in 16544 unique sequences.
# Sample 255 - 38711 reads in 16115 unique sequences.
# Sample 256 - 39210 reads in 16110 unique sequences.
# Sample 257 - 24130 reads in 10223 unique sequences.
# Sample 258 - 39305 reads in 14766 unique sequences.
# Sample 259 - 40914 reads in 17230 unique sequences.
# Sample 260 - 41179 reads in 16384 unique sequences.
# Sample 261 - 40402 reads in 15891 unique sequences.
# Sample 262 - 39267 reads in 15843 unique sequences.

# %%
# Merge paired reads 
mergers <- mergePairs(dadaFs, derepFs, dadaRs, derepRs, verbose=TRUE)

# Back up generated object 
save(mergers, file="output/2_dada2/objects/mergers.RData")
# Out:
# 20673 paired-reads (in 776 unique pairings) successfully merged out of 23904 (in 2924 pairings) input.
# 12075 paired-reads (in 579 unique pairings) successfully merged out of 17100 (in 3916 pairings) input.
# 14648 paired-reads (in 693 unique pairings) successfully merged out of 18802 (in 3440 pairings) input.
# 12353 paired-reads (in 549 unique pairings) successfully merged out of 16082 (in 3053 pairings) input.
# 27032 paired-reads (in 1129 unique pairings) successfully merged out of 37105 (in 7964 pairings) input.
# 27277 paired-reads (in 1214 unique pairings) successfully merged out of 36453 (in 7168 pairings) input.
# 9906 paired-reads (in 513 unique pairings) successfully merged out of 14482 (in 3661 pairings) input.
# 23659 paired-reads (in 909 unique pairings) successfully merged out of 32962 (in 6922 pairings) input.
# 28306 paired-reads (in 1368 unique pairings) successfully merged out of 35564 (in 5935 pairings) input.
# 28513 paired-reads (in 1282 unique pairings) successfully merged out of 39923 (in 9235 pairings) input.
# 26861 paired-reads (in 1074 unique pairings) successfully merged out of 35969 (in 7236 pairings) input.
# 15831 paired-reads (in 623 unique pairings) successfully merged out of 20832 (in 4015 pairings) input.
# 15562 paired-reads (in 783 unique pairings) successfully merged out of 19867 (in 3669 pairings) input.
# 15290 paired-reads (in 679 unique pairings) successfully merged out of 19987 (in 3810 pairings) input.
# 32085 paired-reads (in 1472 unique pairings) successfully merged out of 44831 (in 10043 pairings) input.
# 4 paired-reads (in 1 unique pairings) successfully merged out of 4 (in 1 pairings) input.
# 25926 paired-reads (in 1120 unique pairings) successfully merged out of 34803 (in 6836 pairings) input.
# 12089 paired-reads (in 611 unique pairings) successfully merged out of 16214 (in 3438 pairings) input.
# 27401 paired-reads (in 1266 unique pairings) successfully merged out of 39230 (in 9366 pairings) input.
# 25151 paired-reads (in 1023 unique pairings) successfully merged out of 34708 (in 7495 pairings) input.
# 27918 paired-reads (in 1161 unique pairings) successfully merged out of 37912 (in 8073 pairings) input.
# 24471 paired-reads (in 1228 unique pairings) successfully merged out of 34477 (in 8471 pairings) input.
# 2 paired-reads (in 1 unique pairings) successfully merged out of 2 (in 1 pairings) input.
# 14007 paired-reads (in 657 unique pairings) successfully merged out of 19191 (in 4288 pairings) input.
# 13012 paired-reads (in 642 unique pairings) successfully merged out of 17560 (in 3650 pairings) input.
# 15200 paired-reads (in 686 unique pairings) successfully merged out of 19922 (in 3993 pairings) input.
# 30843 paired-reads (in 1110 unique pairings) successfully merged out of 36382 (in 4017 pairings) input.
# 25586 paired-reads (in 1140 unique pairings) successfully merged out of 34765 (in 7517 pairings) input.
# 11568 paired-reads (in 570 unique pairings) successfully merged out of 17173 (in 4408 pairings) input.
# 21375 paired-reads (in 874 unique pairings) successfully merged out of 31490 (in 7535 pairings) input.
# 19772 paired-reads (in 929 unique pairings) successfully merged out of 28717 (in 7240 pairings) input.
# 26181 paired-reads (in 1178 unique pairings) successfully merged out of 35202 (in 7455 pairings) input.
# 25668 paired-reads (in 1126 unique pairings) successfully merged out of 35451 (in 7664 pairings) input.
# 21924 paired-reads (in 1047 unique pairings) successfully merged out of 31826 (in 7859 pairings) input.
# 25826 paired-reads (in 1052 unique pairings) successfully merged out of 33881 (in 6601 pairings) input.
# 15445 paired-reads (in 786 unique pairings) successfully merged out of 21794 (in 5332 pairings) input.
# 11794 paired-reads (in 630 unique pairings) successfully merged out of 16708 (in 3947 pairings) input.
# 11499 paired-reads (in 637 unique pairings) successfully merged out of 16846 (in 4324 pairings) input.
# 11583 paired-reads (in 583 unique pairings) successfully merged out of 17218 (in 4470 pairings) input.
# 11196 paired-reads (in 601 unique pairings) successfully merged out of 17148 (in 4476 pairings) input.
# 10296 paired-reads (in 442 unique pairings) successfully merged out of 14702 (in 3337 pairings) input.
# 14848 paired-reads (in 681 unique pairings) successfully merged out of 20217 (in 4451 pairings) input.
# 17319 paired-reads (in 789 unique pairings) successfully merged out of 24095 (in 5593 pairings) input.
# 12875 paired-reads (in 615 unique pairings) successfully merged out of 18804 (in 4620 pairings) input.
# 13809 paired-reads (in 775 unique pairings) successfully merged out of 20041 (in 5186 pairings) input.
# 10986 paired-reads (in 513 unique pairings) successfully merged out of 16118 (in 4165 pairings) input.
# 15013 paired-reads (in 726 unique pairings) successfully merged out of 21128 (in 4885 pairings) input.
# 8408 paired-reads (in 430 unique pairings) successfully merged out of 12018 (in 2945 pairings) input.
# 20892 paired-reads (in 687 unique pairings) successfully merged out of 25264 (in 3679 pairings) input.
# 16232 paired-reads (in 616 unique pairings) successfully merged out of 20888 (in 3530 pairings) input.
# 17014 paired-reads (in 756 unique pairings) successfully merged out of 20973 (in 3337 pairings) input.
# 13699 paired-reads (in 604 unique pairings) successfully merged out of 18747 (in 4176 pairings) input.
# 18283 paired-reads (in 905 unique pairings) successfully merged out of 24307 (in 4871 pairings) input.
# 15099 paired-reads (in 670 unique pairings) successfully merged out of 19461 (in 3566 pairings) input.
# 18408 paired-reads (in 866 unique pairings) successfully merged out of 26686 (in 6374 pairings) input.
# 54802 paired-reads (in 1677 unique pairings) successfully merged out of 71068 (in 12325 pairings) input.
# 13673 paired-reads (in 639 unique pairings) successfully merged out of 19376 (in 4469 pairings) input.
# 29285 paired-reads (in 1242 unique pairings) successfully merged out of 38199 (in 7003 pairings) input.
# 24611 paired-reads (in 1063 unique pairings) successfully merged out of 33843 (in 7437 pairings) input.
# 15760 paired-reads (in 732 unique pairings) successfully merged out of 19343 (in 3138 pairings) input.
# 15735 paired-reads (in 744 unique pairings) successfully merged out of 21534 (in 4710 pairings) input.
# 14575 paired-reads (in 748 unique pairings) successfully merged out of 19977 (in 4426 pairings) input.
# 14552 paired-reads (in 667 unique pairings) successfully merged out of 19700 (in 4118 pairings) input.
# 21580 paired-reads (in 965 unique pairings) successfully merged out of 31564 (in 7766 pairings) input.
# 26272 paired-reads (in 1053 unique pairings) successfully merged out of 35965 (in 7528 pairings) input.
# 13301 paired-reads (in 597 unique pairings) successfully merged out of 19883 (in 4787 pairings) input.
# 23202 paired-reads (in 1024 unique pairings) successfully merged out of 32768 (in 7748 pairings) input.
# 22240 paired-reads (in 1073 unique pairings) successfully merged out of 31553 (in 7627 pairings) input.
# 11065 paired-reads (in 397 unique pairings) successfully merged out of 13843 (in 2291 pairings) input.
# 13401 paired-reads (in 654 unique pairings) successfully merged out of 18134 (in 3946 pairings) input.
# 19155 paired-reads (in 605 unique pairings) successfully merged out of 21555 (in 2002 pairings) input.
# 20685 paired-reads (in 661 unique pairings) successfully merged out of 24307 (in 2600 pairings) input.
# 23528 paired-reads (in 977 unique pairings) successfully merged out of 32959 (in 7043 pairings) input.
# 27885 paired-reads (in 1006 unique pairings) successfully merged out of 36257 (in 5959 pairings) input.
# 14715 paired-reads (in 609 unique pairings) successfully merged out of 19068 (in 3541 pairings) input.
# 28039 paired-reads (in 1049 unique pairings) successfully merged out of 37618 (in 7076 pairings) input.
# 27397 paired-reads (in 1142 unique pairings) successfully merged out of 36191 (in 6820 pairings) input.
# 12428 paired-reads (in 409 unique pairings) successfully merged out of 15115 (in 2175 pairings) input.
# 14324 paired-reads (in 638 unique pairings) successfully merged out of 19011 (in 3897 pairings) input.
# 15067 paired-reads (in 729 unique pairings) successfully merged out of 19449 (in 3740 pairings) input.
# 23255 paired-reads (in 1004 unique pairings) successfully merged out of 32720 (in 7153 pairings) input.
# 27848 paired-reads (in 1313 unique pairings) successfully merged out of 37372 (in 7718 pairings) input.
# 9 paired-reads (in 2 unique pairings) successfully merged out of 9 (in 2 pairings) input.
# 11297 paired-reads (in 564 unique pairings) successfully merged out of 17321 (in 4494 pairings) input.
# 20638 paired-reads (in 967 unique pairings) successfully merged out of 31446 (in 8258 pairings) input.
# 22452 paired-reads (in 1069 unique pairings) successfully merged out of 31940 (in 7613 pairings) input.
# 25622 paired-reads (in 1128 unique pairings) successfully merged out of 34704 (in 7431 pairings) input.
# 23148 paired-reads (in 1063 unique pairings) successfully merged out of 32407 (in 7555 pairings) input.
# 27355 paired-reads (in 1280 unique pairings) successfully merged out of 38196 (in 8720 pairings) input.
# 21582 paired-reads (in 972 unique pairings) successfully merged out of 30151 (in 6898 pairings) input.
# 15341 paired-reads (in 552 unique pairings) successfully merged out of 18006 (in 2265 pairings) input.
# 12268 paired-reads (in 640 unique pairings) successfully merged out of 17096 (in 3952 pairings) input.
# 18277 paired-reads (in 874 unique pairings) successfully merged out of 24837 (in 5288 pairings) input.
# 13601 paired-reads (in 699 unique pairings) successfully merged out of 18318 (in 3979 pairings) input.
# 12690 paired-reads (in 614 unique pairings) successfully merged out of 17317 (in 3787 pairings) input.
# 26211 paired-reads (in 987 unique pairings) successfully merged out of 34462 (in 5885 pairings) input.
# 14969 paired-reads (in 699 unique pairings) successfully merged out of 21106 (in 4944 pairings) input.
# 13693 paired-reads (in 641 unique pairings) successfully merged out of 19404 (in 4462 pairings) input.
# 16253 paired-reads (in 739 unique pairings) successfully merged out of 22227 (in 4678 pairings) input.
# 14507 paired-reads (in 652 unique pairings) successfully merged out of 20213 (in 4528 pairings) input.
# 15761 paired-reads (in 754 unique pairings) successfully merged out of 21319 (in 4762 pairings) input.
# 18448 paired-reads (in 758 unique pairings) successfully merged out of 24730 (in 5120 pairings) input.
# 18741 paired-reads (in 853 unique pairings) successfully merged out of 25827 (in 5843 pairings) input.
# 17525 paired-reads (in 722 unique pairings) successfully merged out of 23227 (in 4525 pairings) input.
# 17062 paired-reads (in 815 unique pairings) successfully merged out of 23713 (in 5521 pairings) input.
# 16804 paired-reads (in 755 unique pairings) successfully merged out of 23055 (in 4959 pairings) input.
# 15358 paired-reads (in 739 unique pairings) successfully merged out of 21034 (in 4714 pairings) input.
# 13341 paired-reads (in 535 unique pairings) successfully merged out of 17745 (in 3423 pairings) input.
# 16057 paired-reads (in 769 unique pairings) successfully merged out of 22123 (in 4784 pairings) input.
# 17779 paired-reads (in 785 unique pairings) successfully merged out of 22544 (in 4036 pairings) input.
# 12285 paired-reads (in 620 unique pairings) successfully merged out of 17350 (in 4162 pairings) input.
# 16264 paired-reads (in 770 unique pairings) successfully merged out of 22098 (in 4674 pairings) input.
# 12656 paired-reads (in 608 unique pairings) successfully merged out of 18270 (in 4442 pairings) input.
# 23621 paired-reads (in 964 unique pairings) successfully merged out of 32928 (in 6923 pairings) input.
# 26796 paired-reads (in 1254 unique pairings) successfully merged out of 37998 (in 9027 pairings) input.
# 10484 paired-reads (in 499 unique pairings) successfully merged out of 14491 (in 3204 pairings) input.
# 24871 paired-reads (in 1113 unique pairings) successfully merged out of 35238 (in 8176 pairings) input.
# 28278 paired-reads (in 1263 unique pairings) successfully merged out of 39841 (in 9201 pairings) input.
# 26026 paired-reads (in 981 unique pairings) successfully merged out of 34752 (in 6655 pairings) input.
# 25176 paired-reads (in 1107 unique pairings) successfully merged out of 35006 (in 7879 pairings) input.
# 23981 paired-reads (in 1132 unique pairings) successfully merged out of 33434 (in 7429 pairings) input.
# 16564 paired-reads (in 578 unique pairings) successfully merged out of 20285 (in 3025 pairings) input.
# 14610 paired-reads (in 670 unique pairings) successfully merged out of 20252 (in 4574 pairings) input.
# 15262 paired-reads (in 709 unique pairings) successfully merged out of 21149 (in 4586 pairings) input.
# 7470 paired-reads (in 402 unique pairings) successfully merged out of 10963 (in 2681 pairings) input.
# No paired-reads (in ZERO unique pairings) successfully merged out of 28 pairings) input.
# 19851 paired-reads (in 912 unique pairings) successfully merged out of 30739 (in 8345 pairings) input.
# 12695 paired-reads (in 589 unique pairings) successfully merged out of 19164 (in 4651 pairings) input.
# 27426 paired-reads (in 1137 unique pairings) successfully merged out of 38942 (in 8507 pairings) input.
# 25848 paired-reads (in 1229 unique pairings) successfully merged out of 36689 (in 8976 pairings) input.
# 509 paired-reads (in 61 unique pairings) successfully merged out of 894 (in 226 pairings) input.
# 13132 paired-reads (in 468 unique pairings) successfully merged out of 16970 (in 3141 pairings) input.
# 14054 paired-reads (in 669 unique pairings) successfully merged out of 19246 (in 4232 pairings) input.
# 18932 paired-reads (in 1004 unique pairings) successfully merged out of 25195 (in 5280 pairings) input.
# 13326 paired-reads (in 758 unique pairings) successfully merged out of 18634 (in 4387 pairings) input.
# 14553 paired-reads (in 779 unique pairings) successfully merged out of 20122 (in 4674 pairings) input.
# 12341 paired-reads (in 612 unique pairings) successfully merged out of 16976 (in 3806 pairings) input.
# 19133 paired-reads (in 829 unique pairings) successfully merged out of 27493 (in 6266 pairings) input.
# 15512 paired-reads (in 674 unique pairings) successfully merged out of 21112 (in 4476 pairings) input.
# 27802 paired-reads (in 1368 unique pairings) successfully merged out of 39356 (in 9327 pairings) input.
# 28645 paired-reads (in 1361 unique pairings) successfully merged out of 38981 (in 8376 pairings) input.
# 15386 paired-reads (in 730 unique pairings) successfully merged out of 21533 (in 4974 pairings) input.
# 19909 paired-reads (in 752 unique pairings) successfully merged out of 25220 (in 3885 pairings) input.
# 15151 paired-reads (in 766 unique pairings) successfully merged out of 21501 (in 5012 pairings) input.
# 15166 paired-reads (in 716 unique pairings) successfully merged out of 20218 (in 4100 pairings) input.
# 15723 paired-reads (in 663 unique pairings) successfully merged out of 21134 (in 4302 pairings) input.
# 16971 paired-reads (in 829 unique pairings) successfully merged out of 23070 (in 4932 pairings) input.
# 17396 paired-reads (in 866 unique pairings) successfully merged out of 24382 (in 5714 pairings) input.
# 19273 paired-reads (in 970 unique pairings) successfully merged out of 26291 (in 6044 pairings) input.
# 13903 paired-reads (in 666 unique pairings) successfully merged out of 18909 (in 4066 pairings) input.
# 17246 paired-reads (in 895 unique pairings) successfully merged out of 23345 (in 4931 pairings) input.
# 18405 paired-reads (in 671 unique pairings) successfully merged out of 21804 (in 3056 pairings) input.
# 13810 paired-reads (in 707 unique pairings) successfully merged out of 18955 (in 4238 pairings) input.
# 17665 paired-reads (in 724 unique pairings) successfully merged out of 23123 (in 4409 pairings) input.
# 14924 paired-reads (in 703 unique pairings) successfully merged out of 19629 (in 4002 pairings) input.
# 12983 paired-reads (in 697 unique pairings) successfully merged out of 17988 (in 4002 pairings) input.
# 25017 paired-reads (in 1162 unique pairings) successfully merged out of 34367 (in 7435 pairings) input.
# 21754 paired-reads (in 1154 unique pairings) successfully merged out of 32595 (in 8415 pairings) input.
# 23739 paired-reads (in 961 unique pairings) successfully merged out of 31613 (in 6088 pairings) input.
# 21325 paired-reads (in 1057 unique pairings) successfully merged out of 32779 (in 9042 pairings) input.
# 13123 paired-reads (in 610 unique pairings) successfully merged out of 18227 (in 4076 pairings) input.
# 24438 paired-reads (in 1140 unique pairings) successfully merged out of 34769 (in 8484 pairings) input.
# 16110 paired-reads (in 667 unique pairings) successfully merged out of 20963 (in 3972 pairings) input.
# 16745 paired-reads (in 741 unique pairings) successfully merged out of 22541 (in 4795 pairings) input.
# 12261 paired-reads (in 661 unique pairings) successfully merged out of 17665 (in 4373 pairings) input.
# 15188 paired-reads (in 777 unique pairings) successfully merged out of 21651 (in 5416 pairings) input.
# 15103 paired-reads (in 737 unique pairings) successfully merged out of 21423 (in 5077 pairings) input.
# 21864 paired-reads (in 978 unique pairings) successfully merged out of 30762 (in 7073 pairings) input.
# 13710 paired-reads (in 716 unique pairings) successfully merged out of 19993 (in 5113 pairings) input.
# 16386 paired-reads (in 808 unique pairings) successfully merged out of 23552 (in 5846 pairings) input.
# 15835 paired-reads (in 774 unique pairings) successfully merged out of 22205 (in 5256 pairings) input.
# 11593 paired-reads (in 601 unique pairings) successfully merged out of 16693 (in 4050 pairings) input.
# 19269 paired-reads (in 867 unique pairings) successfully merged out of 26651 (in 6056 pairings) input.
# 14049 paired-reads (in 586 unique pairings) successfully merged out of 17579 (in 2952 pairings) input.
# 12440 paired-reads (in 595 unique pairings) successfully merged out of 17424 (in 4082 pairings) input.
# 14260 paired-reads (in 742 unique pairings) successfully merged out of 18751 (in 3891 pairings) input.
# 12446 paired-reads (in 649 unique pairings) successfully merged out of 17378 (in 4178 pairings) input.
# 26701 paired-reads (in 1133 unique pairings) successfully merged out of 37875 (in 8524 pairings) input.
# 17559 paired-reads (in 682 unique pairings) successfully merged out of 25146 (in 5484 pairings) input.
# 11557 paired-reads (in 564 unique pairings) successfully merged out of 17133 (in 4305 pairings) input.
# 20576 paired-reads (in 897 unique pairings) successfully merged out of 30202 (in 7283 pairings) input.
# 21995 paired-reads (in 941 unique pairings) successfully merged out of 30364 (in 6619 pairings) input.
# 17829 paired-reads (in 734 unique pairings) successfully merged out of 22627 (in 3807 pairings) input.
# 13922 paired-reads (in 667 unique pairings) successfully merged out of 18575 (in 3753 pairings) input.
# 15509 paired-reads (in 771 unique pairings) successfully merged out of 20341 (in 4080 pairings) input.
# 1617 paired-reads (in 114 unique pairings) successfully merged out of 2446 (in 569 pairings) input.
# 25351 paired-reads (in 1167 unique pairings) successfully merged out of 34571 (in 7541 pairings) input.
# 21780 paired-reads (in 822 unique pairings) successfully merged out of 28699 (in 5236 pairings) input.
# 15996 paired-reads (in 604 unique pairings) successfully merged out of 21743 (in 4305 pairings) input.
# 25462 paired-reads (in 1242 unique pairings) successfully merged out of 35917 (in 8558 pairings) input.
# 21394 paired-reads (in 988 unique pairings) successfully merged out of 29388 (in 6325 pairings) input.
# 27024 paired-reads (in 1105 unique pairings) successfully merged out of 36728 (in 7830 pairings) input.
# 3884 paired-reads (in 182 unique pairings) successfully merged out of 5892 (in 1322 pairings) input.
# 22408 paired-reads (in 1208 unique pairings) successfully merged out of 31917 (in 8006 pairings) input.
# 19347 paired-reads (in 944 unique pairings) successfully merged out of 26883 (in 6267 pairings) input.
# 11830 paired-reads (in 668 unique pairings) successfully merged out of 17620 (in 4614 pairings) input.
# 16776 paired-reads (in 799 unique pairings) successfully merged out of 20294 (in 3112 pairings) input.
# 16135 paired-reads (in 778 unique pairings) successfully merged out of 22291 (in 4920 pairings) input.
# 13522 paired-reads (in 626 unique pairings) successfully merged out of 19273 (in 4209 pairings) input.
# 13960 paired-reads (in 684 unique pairings) successfully merged out of 19189 (in 4288 pairings) input.
# 1469 paired-reads (in 68 unique pairings) successfully merged out of 1764 (in 230 pairings) input.
# 26615 paired-reads (in 1138 unique pairings) successfully merged out of 37989 (in 8966 pairings) input.
# 12652 paired-reads (in 645 unique pairings) successfully merged out of 19103 (in 5050 pairings) input.
# 12715 paired-reads (in 655 unique pairings) successfully merged out of 19338 (in 4965 pairings) input.
# 13017 paired-reads (in 639 unique pairings) successfully merged out of 18679 (in 4566 pairings) input.
# 14245 paired-reads (in 567 unique pairings) successfully merged out of 19241 (in 4027 pairings) input.
# 16645 paired-reads (in 733 unique pairings) successfully merged out of 21971 (in 4474 pairings) input.
# 14372 paired-reads (in 605 unique pairings) successfully merged out of 20329 (in 4586 pairings) input.
# 11797 paired-reads (in 528 unique pairings) successfully merged out of 15503 (in 3101 pairings) input.
# 14981 paired-reads (in 785 unique pairings) successfully merged out of 21544 (in 5073 pairings) input.
# 18445 paired-reads (in 732 unique pairings) successfully merged out of 24586 (in 5017 pairings) input.
# 15457 paired-reads (in 686 unique pairings) successfully merged out of 20948 (in 4439 pairings) input.
# 13095 paired-reads (in 591 unique pairings) successfully merged out of 17965 (in 3574 pairings) input.
# 13181 paired-reads (in 485 unique pairings) successfully merged out of 15640 (in 2049 pairings) input.
# 15787 paired-reads (in 682 unique pairings) successfully merged out of 21203 (in 4416 pairings) input.
# 17893 paired-reads (in 814 unique pairings) successfully merged out of 22721 (in 3974 pairings) input.
# 16554 paired-reads (in 881 unique pairings) successfully merged out of 21921 (in 4554 pairings) input.
# 12111 paired-reads (in 570 unique pairings) successfully merged out of 16423 (in 3504 pairings) input.
# 12649 paired-reads (in 545 unique pairings) successfully merged out of 16489 (in 3143 pairings) input.
# 15608 paired-reads (in 694 unique pairings) successfully merged out of 20672 (in 3940 pairings) input.
# 10546 paired-reads (in 634 unique pairings) successfully merged out of 16003 (in 4301 pairings) input.
# 14160 paired-reads (in 729 unique pairings) successfully merged out of 20825 (in 5310 pairings) input.
# 14122 paired-reads (in 713 unique pairings) successfully merged out of 19508 (in 4555 pairings) input.
# 16927 paired-reads (in 740 unique pairings) successfully merged out of 22698 (in 4733 pairings) input.
# 17567 paired-reads (in 697 unique pairings) successfully merged out of 23100 (in 4343 pairings) input.
# 12848 paired-reads (in 574 unique pairings) successfully merged out of 17362 (in 3585 pairings) input.
# 10606 paired-reads (in 480 unique pairings) successfully merged out of 14596 (in 2982 pairings) input.
# 13005 paired-reads (in 631 unique pairings) successfully merged out of 18626 (in 4472 pairings) input.
# 11858 paired-reads (in 606 unique pairings) successfully merged out of 16905 (in 3982 pairings) input.
# 12597 paired-reads (in 599 unique pairings) successfully merged out of 16847 (in 3527 pairings) input.
# 11644 paired-reads (in 505 unique pairings) successfully merged out of 15396 (in 2967 pairings) input.
# 10734 paired-reads (in 544 unique pairings) successfully merged out of 15238 (in 3602 pairings) input.
# 7328 paired-reads (in 315 unique pairings) successfully merged out of 9577 (in 1829 pairings) input.
# 12050 paired-reads (in 593 unique pairings) successfully merged out of 17263 (in 4221 pairings) input.
# 14804 paired-reads (in 695 unique pairings) successfully merged out of 20215 (in 4183 pairings) input.
# 13149 paired-reads (in 676 unique pairings) successfully merged out of 18956 (in 4482 pairings) input.
# 23302 paired-reads (in 1127 unique pairings) successfully merged out of 34310 (in 8406 pairings) input.
# 11063 paired-reads (in 570 unique pairings) successfully merged out of 16470 (in 4206 pairings) input.
# 20506 paired-reads (in 983 unique pairings) successfully merged out of 30744 (in 7966 pairings) input.
# 24779 paired-reads (in 1228 unique pairings) successfully merged out of 35368 (in 8672 pairings) input.
# 15000 paired-reads (in 511 unique pairings) successfully merged out of 18487 (in 2864 pairings) input.
# 13923 paired-reads (in 730 unique pairings) successfully merged out of 19438 (in 4666 pairings) input.
# 13572 paired-reads (in 687 unique pairings) successfully merged out of 17820 (in 3702 pairings) input.
# 14674 paired-reads (in 709 unique pairings) successfully merged out of 20086 (in 4466 pairings) input.
# 20936 paired-reads (in 970 unique pairings) successfully merged out of 30961 (in 7382 pairings) input.
# 25435 paired-reads (in 1083 unique pairings) successfully merged out of 35876 (in 7724 pairings) input.
# 11698 paired-reads (in 643 unique pairings) successfully merged out of 17804 (in 4748 pairings) input.
# 27081 paired-reads (in 1227 unique pairings) successfully merged out of 38798 (in 9053 pairings) input.
# 19682 paired-reads (in 932 unique pairings) successfully merged out of 29278 (in 7209 pairings) input.
# 16862 paired-reads (in 670 unique pairings) successfully merged out of 20708 (in 3181 pairings) input.
# 14714 paired-reads (in 689 unique pairings) successfully merged out of 20000 (in 4393 pairings) input.
# 13404 paired-reads (in 657 unique pairings) successfully merged out of 17837 (in 3689 pairings) input.
# 12858 paired-reads (in 673 unique pairings) successfully merged out of 17485 (in 3880 pairings) input.
# 25520 paired-reads (in 1112 unique pairings) successfully merged out of 35523 (in 7578 pairings) input.
# 23747 paired-reads (in 1040 unique pairings) successfully merged out of 33225 (in 7012 pairings) input.
# 22517 paired-reads (in 1133 unique pairings) successfully merged out of 33231 (in 8504 pairings) input.
# 14322 paired-reads (in 716 unique pairings) successfully merged out of 19866 (in 4460 pairings) input.
# 24722 paired-reads (in 1165 unique pairings) successfully merged out of 34168 (in 7201 pairings) input.
# 24874 paired-reads (in 1121 unique pairings) successfully merged out of 35018 (in 8073 pairings) input.
# 26712 paired-reads (in 1071 unique pairings) successfully merged out of 35448 (in 7131 pairings) input.
# 24502 paired-reads (in 1095 unique pairings) successfully merged out of 34498 (in 7924 pairings) input.
# 24338 paired-reads (in 1064 unique pairings) successfully merged out of 33089 (in 7144 pairings) input.

# %%
# Construct sequence table
seqtab <- makeSequenceTable(mergers)

# Check visually reads distribution by their merged length
reads.per.seqlen <- tapply(colSums(seqtab), factor(nchar(getSequences(seqtab))), sum)

df <- data.frame(length=as.numeric(names(reads.per.seqlen)), count=reads.per.seqlen)

readsDisr <- ggplot(data=df, aes(x=length, y=count)) + geom_col() + theme_bw()

# Save the plot 
ggsave("output/2_dada2/diagnostic_plots/leng_reads_distr.pdf", plot = readsDisr)

# Trim reads outside of reads distribution borders 
seqtab2 <- seqtab[,nchar(colnames(seqtab)) %in% seq(400, 430)]
# Out:
# Saving 6.67 x 6.67 in image

# %%
# Remove chimeras (will be majority of variants)
seqtab.nochim <- removeBimeraDenovo(seqtab2, method="consensus", multithread=TRUE, verbose=TRUE)

# Save ASV as R object and csv table 
save(seqtab.nochim, file = "output/2_dada2/objects/seqtab_nochim.RData")

write.csv(seqtab.nochim, file = "output/2_dada2/seqtab_nochim.csv")
# Out:
# Identified 33673 bimeras out of 48832 input sequences.

# %%
# Check how many sequenses get through 
getN <- function(x) sum(getUniques(x))

track <- cbind(out, sapply(dadaFs, getN), sapply(dadaRs, getN), 
               sapply(mergers, getN), rowSums(seqtab.nochim))

# If processing a single sample, remove the sapply calls: e.g. 
# replace sapply(dadaFs, getN) with getN(dadaFs)

colnames(track) <- c("input", "filtered", "denoisedF", "denoisedR", "merged", "nonchim")

rownames(track) <- sample.names

write.csv(track, file = "output/2_dada2/diagnostic_plots/track.csv")

# %%
load("output/2_dada2/objects/seqtab_nochim.RData")

# %%
# Taxonomy assignment  
#  Assign taxonomy using classical method 
taxa <- assignTaxonomy(seqtab.nochim, 
                       "resourses/silva_nr_v138_train_set.fa.gz",
                       multithread = TRUE)

# Save taxonomy table as csv and R object
write.csv(x = taxa, "output/2_dada2/taxa.csv")

save(taxa, file ="output/2_dada2/objects/taxa.RData")

# %%
# Read in metadata for samples 
metadata_final <- read.csv("output/1_shedding_analysis/metadata_f.csv")

rownames(metadata_final) <- metadata_final$NewId

# %%
rownames(seqtab.nochim) <- gsub("\\.gz", "", rownames(seqtab.nochim))

# %%
# Combine taxonomic table, ASV count table and metadata into a pholoseq object. 
ps <- phyloseq(otu_table(seqtab.nochim, taxa_are_rows = FALSE), 
               sample_data(metadata_final), 
               tax_table(taxa))

# Save phyloseq object 
save(ps, file = "output/2_dada2/phyloseq0.RData")
saveRDS(ps, "output/2_dada2/phyloseq0.rds")
